# %%
import sys
from pathlib import Path
import json

import pandas as pd
import gtfs_kit as gk
import itertools
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from datetime import datetime

# %%
#setting GTFS data directory path for loading
DIR = Path('..')
sys.path.append(str(DIR))
DATA_DIR = DIR/'gtfs_data/' #GTFS datasets to be processed must be downloaded or stored here.

#loading GTFS data and list the feed components. You may edit the path variable depending upon where the GTFS dataset is stored.
path = DATA_DIR/'gtfs-openov-nl.zip'
gk.list_feed(path)

#Setting GTFS data details. REGION_NAME attribute is the region covered by the available GTFS dataset. For the openov dataset, it is the Netherlands.
REGION_NAME = 'netherlands'

#Set the calendar day(s) for generating the time schedule table in YYYYMMDD string format
CAL_DATE = '20200131'
date_text = 'Jan_sunday_20200131'

# %%
routes = pd.read_csv(DIR/'gtfs_data/{}/routes.txt'.format(REGION_NAME), low_memory=False)
routes = routes[['route_id', 'route_type']]
routes.head()
# Out:
#    route_id  route_type
# 0     67248           3
# 1     66859           3
# 2     66873           3
# 3     66872           3
# 4     67392           2

# %%
calendar_dates = pd.read_csv(DIR/'gtfs_data/{}/calendar_dates.txt'.format(REGION_NAME), low_memory=False)
calendar_dates.head()
# Out:
#    service_id      date  exception_type
# 0           1  20200120               1
# 1           2  20200120               1
# 2           2  20200210               1
# 3           3  20200120               1
# 4           3  20200203               1

# %%
#Subsetting services on the calendar date
services_of_interest = calendar_dates.query('date == {}'.format(CAL_DATE)).service_id.values
services_of_interest[0:5]
# Out:
# array([41, 67, 69, 73, 74], dtype=int64)

# %%
#Subsetting the trips for the date of interest
trips = pd.read_csv(DIR/'gtfs_data/{}/trips.txt'.format(REGION_NAME), low_memory=False)
trips = trips[['route_id', 'service_id', 'trip_id', 'shape_id', 'direction_id']]
trips = trips.loc[trips['service_id'].isin(services_of_interest)]
print(trips.head())

trips_of_interest = trips.trip_id.values
print(trips_of_interest[0:5])
# Out:
#     route_id  service_id    trip_id  shape_id  direction_id
# 17     17779         231   98650022  799314.0             1
# 18     41216         232  103436999  800108.0             0
# 19     62265         415  103577453  857372.0             1
# 20     62265         415  103577827  857432.0             0
# 21     62265         415  103583924  857372.0             1
# [ 98650022 103436999 103577453 103577827 103583924]

# %%
stop_times = pd.read_csv(DIR/'gtfs_data/{}/stop_times.txt'.format(REGION_NAME), low_memory=False)
stop_times = stop_times.loc[stop_times['trip_id'].isin(trips_of_interest)]
stop_times['stop_id'] = stop_times['stop_id'].astype(str)

stop_times = stop_times[['trip_id', 'stop_sequence', 'stop_id', 'arrival_time', 'departure_time']]
for string in range(24, 50):
    stop_times = stop_times[~stop_times.arrival_time.str.startswith("{}:".format(string))]
stop_times.head()
# Out:
#       trip_id  stop_sequence stop_id arrival_time departure_time
# 28  101870885             30    7195     14:12:00       14:12:00
# 29  101894943             39  650245     09:09:00       09:09:00
# 30  101894943             13  649922     08:48:00       08:48:00
# 31  101894943              7  649942     08:41:00       08:41:00
# 32  101909764             15    6855     15:16:00       15:16:00

# %%
stop_times = pd.merge(stop_times, trips, on="trip_id")
stop_times['arrival_time'] = pd.to_datetime(stop_times['arrival_time'],format= '%H:%M:%S' ).dt.time
stop_times.head()
# Out:
#      trip_id  stop_sequence stop_id arrival_time departure_time  route_id  \
# 0  101870885             30    7195     14:12:00       14:12:00     41726
# 1  101870885             20  221202     14:00:00       14:00:00     41726
# 2  101870885             31    7200     14:13:00       14:13:00     41726
# 3  101870885             13    5950     13:50:00       13:50:00     41726
# 4  101870885             34    7276     14:15:00       14:15:00     41726
#
#    service_id  shape_id  direction_id
# 0        1659  838609.0             1
# 1        1659  838609.0             1
# 2        1659  838609.0             1
# 3        1659  838609.0             1
# 4        1659  838609.0             1

# %%
route_list = stop_times.route_id.unique()
direction_list = stop_times.direction_id.unique()

cat = {
    'route_id': route_list,
    'direction_id' : direction_list
}

order = cat.keys()
time_schedule = pd.DataFrame(itertools.product(*[cat[k] for k in order]), columns=order)
time_schedule['start_time'] = np.nan
time_schedule['stop_sequence'] = np.nan
time_schedule['inter_stop_tt'] = np.nan

time_schedule.head()
# Out:
#    route_id  direction_id  start_time  stop_sequence  inter_stop_tt
# 0     41726             1         NaN            NaN            NaN
# 1     41726             0         NaN            NaN            NaN
# 2     67002             1         NaN            NaN            NaN
# 3     67002             0         NaN            NaN            NaN
# 4     43157             1         NaN            NaN            NaN

# %%
#time_schedule = time_schedule.head(1)
for i in range(time_schedule.shape[0]):
    curr_route_stop_times = stop_times.query('route_id == {0} and direction_id == {1} and stop_sequence == 1'.format(time_schedule.route_id[i], time_schedule.direction_id[i]))
    curr_route_stop_times = curr_route_stop_times.reset_index()
    #print(curr_route_stop_times.head())
    
    if curr_route_stop_times.shape[0] > 0:
        start_times = curr_route_stop_times.arrival_time.sort_values().astype(str)
        start_array = [','.join(ele.split()) for ele in start_times]
        time_schedule.start_time[i] = start_array
        #print(i)

        #adding time intervals between stops
        first_trip_in_curr_route = stop_times.query('trip_id == {}'.format(curr_route_stop_times.trip_id[0]))
        first_trip_in_curr_route = first_trip_in_curr_route.sort_values('stop_sequence')
        #print(first_trip_in_curr_route.head())

        travel_times = pd.to_timedelta(first_trip_in_curr_route['arrival_time'].astype(str)).diff(-1).dt.total_seconds()
        #print(travel_times)
        tt_array = [','.join(ele.split()) for ele in abs(travel_times[:-1]).astype(int).astype(str)]
        time_schedule.inter_stop_tt[i] = tt_array

        stop_sequence = first_trip_in_curr_route.stop_id.astype(str)
        stop_array = [','.join(ele.split()) for ele in stop_sequence]
        time_schedule.stop_sequence[i] = stop_array
    print('route {} in direction {} computed.'.format(time_schedule.route_id[i],time_schedule.direction_id[i]))
    
print(time_schedule)
# Out:
# route 41726 in direction 1 computed.
# route 41726 in direction 0 computed.
# route 67002 in direction 1 computed.
# route 67002 in direction 0 computed.
# route 43157 in direction 1 computed.
# route 43157 in direction 0 computed.
# route 200 in direction 1 computed.
# route 200 in direction 0 computed.
# route 206 in direction 1 computed.
# route 206 in direction 0 computed.
# route 41734 in direction 1 computed.
# route 41734 in direction 0 computed.
# route 53530 in direction 1 computed.
# route 53530 in direction 0 computed.
# route 41866 in direction 1 computed.
# route 41866 in direction 0 computed.
# route 67083 in direction 1 computed.
# route 67083 in direction 0 computed.
# route 67079 in direction 1 computed.
# route 67079 in direction 0 computed.
# route 63410 in direction 1 computed.
# route 63410 in direction 0 computed.
# route 57594 in direction 1 computed.
# route 57594 in direction 0 computed.
# route 60897 in direction 1 computed.
# route 60897 in direction 0 computed.
# route 67150 in direction 1 computed.
# route 67150 in direction 0 computed.
# route 32518 in direction 1 computed.
# route 32518 in direction 0 computed.
# route 66913 in direction 1 computed.
# route 66913 in direction 0 computed.
# route 32563 in direction 1 computed.
# route 32563 in direction 0 computed.
# route 30803 in direction 1 computed.
# route 30803 in direction 0 computed.
# route 32579 in direction 1 computed.
# route 32579 in direction 0 computed.
# route 60677 in direction 1 computed.
# route 60677 in direction 0 computed.
# route 61995 in direction 1 computed.
# route 61995 in direction 0 computed.
# route 30503 in direction 1 computed.
# route 30503 in direction 0 computed.
# route 32519 in direction 1 computed.
# route 32519 in direction 0 computed.
# route 54672 in direction 1 computed.
# route 54672 in direction 0 computed.
# route 59759 in direction 1 computed.
# route 59759 in direction 0 computed.
# route 67132 in direction 1 computed.
# route 67132 in direction 0 computed.
# route 32575 in direction 1 computed.
# route 32575 in direction 0 computed.
# route 63415 in direction 1 computed.
# route 63415 in direction 0 computed.
# route 63413 in direction 1 computed.
# route 63413 in direction 0 computed.
# route 57628 in direction 1 computed.
# route 57628 in direction 0 computed.
# route 7190 in direction 1 computed.
# route 7190 in direction 0 computed.
# route 5461 in direction 1 computed.
# route 5461 in direction 0 computed.
# route 5442 in direction 1 computed.
# route 5442 in direction 0 computed.
# route 66738 in direction 1 computed.
# route 66738 in direction 0 computed.
# route 52878 in direction 1 computed.
# route 52878 in direction 0 computed.
# route 5435 in direction 1 computed.
# route 5435 in direction 0 computed.
# route 54145 in direction 1 computed.
# route 54145 in direction 0 computed.
# route 54142 in direction 1 computed.
# route 54142 in direction 0 computed.
# route 54140 in direction 1 computed.
# route 54140 in direction 0 computed.
# route 66807 in direction 1 computed.
# route 66807 in direction 0 computed.
# route 62223 in direction 1 computed.
# route 62223 in direction 0 computed.
# route 455 in direction 1 computed.
# route 455 in direction 0 computed.
# route 43044 in direction 1 computed.
# route 43044 in direction 0 computed.
# route 52864 in direction 1 computed.
# route 52864 in direction 0 computed.
# route 52849 in direction 1 computed.
# route 52849 in direction 0 computed.
# route 30592 in direction 1 computed.
# route 30592 in direction 0 computed.
# route 35200 in direction 1 computed.
# route 35200 in direction 0 computed.
# route 67021 in direction 1 computed.
# route 67021 in direction 0 computed.
# route 57954 in direction 1 computed.
# route 57954 in direction 0 computed.
# route 1774 in direction 1 computed.
# route 1774 in direction 0 computed.
# route 48498 in direction 1 computed.
# route 48498 in direction 0 computed.
# route 67145 in direction 1 computed.
# route 67145 in direction 0 computed.
# route 62235 in direction 1 computed.
# route 62235 in direction 0 computed.
# route 65606 in direction 1 computed.
# route 65606 in direction 0 computed.
# route 6793 in direction 1 computed.
# route 6793 in direction 0 computed.
# route 61934 in direction 1 computed.
# route 61934 in direction 0 computed.
# route 3 in direction 1 computed.
# route 3 in direction 0 computed.
# route 19293 in direction 1 computed.
# route 19293 in direction 0 computed.
# route 41838 in direction 1 computed.
# route 41838 in direction 0 computed.
# route 66819 in direction 1 computed.
# route 66819 in direction 0 computed.
# route 17748 in direction 1 computed.
# route 17748 in direction 0 computed.
# route 2567 in direction 1 computed.
# route 2567 in direction 0 computed.
# route 62270 in direction 1 computed.
# route 62270 in direction 0 computed.
# route 67369 in direction 1 computed.
# route 67369 in direction 0 computed.
# route 65444 in direction 1 computed.
# route 65444 in direction 0 computed.
# route 57867 in direction 1 computed.
# route 57867 in direction 0 computed.
# route 62749 in direction 1 computed.
# route 62749 in direction 0 computed.
# route 62849 in direction 1 computed.
# route 62849 in direction 0 computed.
# route 62727 in direction 1 computed.
# route 62727 in direction 0 computed.
# route 62937 in direction 1 computed.
# route 62937 in direction 0 computed.
# route 62929 in direction 1 computed.
# route 62929 in direction 0 computed.
# route 62618 in direction 1 computed.
# route 62618 in direction 0 computed.
# route 62710 in direction 1 computed.
# route 62710 in direction 0 computed.
# route 62657 in direction 1 computed.
# route 62657 in direction 0 computed.
# route 62771 in direction 1 computed.
# route 62771 in direction 0 computed.
# route 62885 in direction 1 computed.
# route 62885 in direction 0 computed.
# route 62786 in direction 1 computed.
# route 62786 in direction 0 computed.
# route 62878 in direction 1 computed.
# route 62878 in direction 0 computed.
# route 62918 in direction 1 computed.
# route 62918 in direction 0 computed.
# route 62678 in direction 1 computed.
# route 62678 in direction 0 computed.
# route 62661 in direction 1 computed.
# route 62661 in direction 0 computed.
# route 62562 in direction 1 computed.
# route 62562 in direction 0 computed.
# route 62765 in direction 1 computed.
# route 62765 in direction 0 computed.
# route 62895 in direction 1 computed.
# route 62895 in direction 0 computed.
# route 62655 in direction 1 computed.
# route 62655 in direction 0 computed.
# route 62875 in direction 1 computed.
# route 62875 in direction 0 computed.
# route 62675 in direction 1 computed.
# route 62675 in direction 0 computed.
# route 62940 in direction 1 computed.
# route 62940 in direction 0 computed.
# route 67088 in direction 1 computed.
# route 67088 in direction 0 computed.
# route 45111 in direction 1 computed.
# route 45111 in direction 0 computed.
# route 54276 in direction 1 computed.
# route 54276 in direction 0 computed.
# route 54194 in direction 1 computed.
# route 54194 in direction 0 computed.
# route 67300 in direction 1 computed.
# route 67300 in direction 0 computed.
# route 54652 in direction 1 computed.
# route 54652 in direction 0 computed.
# route 61959 in direction 1 computed.
# route 61959 in direction 0 computed.
# route 61965 in direction 1 computed.
# route 61965 in direction 0 computed.
# route 61955 in direction 1 computed.
# route 61955 in direction 0 computed.
# route 2508 in direction 1 computed.
# route 2508 in direction 0 computed.
# route 67155 in direction 1 computed.
# route 67155 in direction 0 computed.
# route 63691 in direction 1 computed.
# route 63691 in direction 0 computed.
# route 67147 in direction 1 computed.
# route 67147 in direction 0 computed.
# route 62233 in direction 1 computed.
# route 62233 in direction 0 computed.
# route 62276 in direction 1 computed.
# route 62276 in direction 0 computed.
# route 1397 in direction 1 computed.
# route 1397 in direction 0 computed.
# route 62266 in direction 1 computed.
# route 62266 in direction 0 computed.
# route 67270 in direction 1 computed.
# route 67270 in direction 0 computed.
# route 62007 in direction 1 computed.
# route 62007 in direction 0 computed.
# route 62232 in direction 1 computed.
# route 62232 in direction 0 computed.
# route 66153 in direction 1 computed.
# route 66153 in direction 0 computed.
# route 67058 in direction 1 computed.
# route 67058 in direction 0 computed.
# route 60673 in direction 1 computed.
# route 60673 in direction 0 computed.
# route 1295 in direction 1 computed.
# route 1295 in direction 0 computed.
# route 63198 in direction 1 computed.
# route 63198 in direction 0 computed.
# route 66664 in direction 1 computed.
# route 66664 in direction 0 computed.
# route 53865 in direction 1 computed.
# route 53865 in direction 0 computed.
# route 67327 in direction 1 computed.
# route 67327 in direction 0 computed.
# route 57685 in direction 1 computed.
# route 57685 in direction 0 computed.
# route 66805 in direction 1 computed.
# route 66805 in direction 0 computed.
# route 54586 in direction 1 computed.
# route 54586 in direction 0 computed.
# route 67091 in direction 1 computed.
# route 67091 in direction 0 computed.
# route 41710 in direction 1 computed.
# route 41710 in direction 0 computed.
# route 255 in direction 1 computed.
# route 255 in direction 0 computed.
# route 195 in direction 1 computed.
# route 195 in direction 0 computed.
# route 1741 in direction 1 computed.
# route 1741 in direction 0 computed.
# route 23097 in direction 1 computed.
# route 23097 in direction 0 computed.
# route 62512 in direction 1 computed.
# route 62512 in direction 0 computed.
# route 60823 in direction 1 computed.
# route 60823 in direction 0 computed.
# route 17658 in direction 1 computed.
# route 17658 in direction 0 computed.
# route 19209 in direction 1 computed.
# route 19209 in direction 0 computed.
# route 32559 in direction 1 computed.
# route 32559 in direction 0 computed.
# route 1615 in direction 1 computed.
# route 1615 in direction 0 computed.
# route 1063 in direction 1 computed.
# route 1063 in direction 0 computed.
# route 67275 in direction 1 computed.
# route 67275 in direction 0 computed.
# route 52505 in direction 1 computed.
# route 52505 in direction 0 computed.
# route 65896 in direction 1 computed.
# route 65896 in direction 0 computed.
# route 67026 in direction 1 computed.
# route 67026 in direction 0 computed.
# route 53855 in direction 1 computed.
# route 53855 in direction 0 computed.
# route 61370 in direction 1 computed.
# route 61370 in direction 0 computed.
# route 60820 in direction 1 computed.
# route 60820 in direction 0 computed.
# route 1166 in direction 1 computed.
# route 1166 in direction 0 computed.
# route 1744 in direction 1 computed.
# route 1744 in direction 0 computed.
# route 41439 in direction 1 computed.
# route 41439 in direction 0 computed.
# route 53478 in direction 1 computed.
# route 53478 in direction 0 computed.
# route 60659 in direction 1 computed.
# route 60659 in direction 0 computed.
# route 67033 in direction 1 computed.
# route 67033 in direction 0 computed.
# route 62811 in direction 1 computed.
# route 62811 in direction 0 computed.
# route 62620 in direction 1 computed.
# route 62620 in direction 0 computed.
# route 62684 in direction 1 computed.
# route 62684 in direction 0 computed.
# route 62857 in direction 1 computed.
# route 62857 in direction 0 computed.
# route 62806 in direction 1 computed.
# route 62806 in direction 0 computed.
# route 62988 in direction 1 computed.
# route 62988 in direction 0 computed.
# route 62980 in direction 1 computed.
# route 62980 in direction 0 computed.
# route 62637 in direction 1 computed.
# route 62637 in direction 0 computed.
# route 62845 in direction 1 computed.
# route 62845 in direction 0 computed.
# route 62679 in direction 1 computed.
# route 62679 in direction 0 computed.
# route 62571 in direction 1 computed.
# route 62571 in direction 0 computed.
# route 62681 in direction 1 computed.
# route 62681 in direction 0 computed.
# route 62830 in direction 1 computed.
# route 62830 in direction 0 computed.
# route 62759 in direction 1 computed.
# route 62759 in direction 0 computed.
# route 62682 in direction 1 computed.
# route 62682 in direction 0 computed.
# route 54251 in direction 1 computed.
# route 54251 in direction 0 computed.
# route 45107 in direction 1 computed.
# route 45107 in direction 0 computed.
# route 54255 in direction 1 computed.
# route 54255 in direction 0 computed.
# route 67608 in direction 1 computed.
# route 67608 in direction 0 computed.
# route 57618 in direction 1 computed.
# route 57618 in direction 0 computed.
# route 62023 in direction 1 computed.
# route 62023 in direction 0 computed.
# route 66773 in direction 1 computed.
# route 66773 in direction 0 computed.
# route 66791 in direction 1 computed.
# route 66791 in direction 0 computed.
# route 52484 in direction 1 computed.
# route 52484 in direction 0 computed.
# route 67014 in direction 1 computed.
# route 67014 in direction 0 computed.
# route 41696 in direction 1 computed.
# route 41696 in direction 0 computed.
# route 62478 in direction 1 computed.
# route 62478 in direction 0 computed.
# route 53349 in direction 1 computed.
# route 53349 in direction 0 computed.
# route 66919 in direction 1 computed.
# route 66919 in direction 0 computed.
# route 63648 in direction 1 computed.
# route 63648 in direction 0 computed.
# route 32539 in direction 1 computed.
# route 32539 in direction 0 computed.
# route 58999 in direction 1 computed.
# route 58999 in direction 0 computed.
# route 61998 in direction 1 computed.
# route 61998 in direction 0 computed.
# route 7095 in direction 1 computed.
# route 7095 in direction 0 computed.
# route 67218 in direction 1 computed.
# route 67218 in direction 0 computed.
# route 11447 in direction 1 computed.
# route 11447 in direction 0 computed.
# route 52914 in direction 1 computed.
# route 52914 in direction 0 computed.
# route 67062 in direction 1 computed.
# route 67062 in direction 0 computed.
# route 61787 in direction 1 computed.
# route 61787 in direction 0 computed.
# route 43025 in direction 1 computed.
# route 43025 in direction 0 computed.
# route 1387 in direction 1 computed.
# route 1387 in direction 0 computed.
# route 63155 in direction 1 computed.
# route 63155 in direction 0 computed.
# route 57643 in direction 1 computed.
# route 57643 in direction 0 computed.
# route 62475 in direction 1 computed.
# route 62475 in direction 0 computed.
# route 67462 in direction 1 computed.
# route 67462 in direction 0 computed.
# route 62547 in direction 1 computed.
# route 62547 in direction 0 computed.
# route 62025 in direction 1 computed.
# route 62025 in direction 0 computed.
# route 62083 in direction 1 computed.
# route 62083 in direction 0 computed.
# route 62563 in direction 1 computed.
# route 62563 in direction 0 computed.
# route 62846 in direction 1 computed.
# route 62846 in direction 0 computed.
# route 62873 in direction 1 computed.
# route 62873 in direction 0 computed.
# route 62669 in direction 1 computed.
# route 62669 in direction 0 computed.
# route 62983 in direction 1 computed.
# route 62983 in direction 0 computed.
# route 54294 in direction 1 computed.
# route 54294 in direction 0 computed.
# route 54278 in direction 1 computed.
# route 54278 in direction 0 computed.
# route 66242 in direction 1 computed.
# route 66242 in direction 0 computed.
# route 66228 in direction 1 computed.
# route 66228 in direction 0 computed.
# route 63131 in direction 1 computed.
# route 63131 in direction 0 computed.
# route 52485 in direction 1 computed.
# route 52485 in direction 0 computed.
# route 67009 in direction 1 computed.
# route 67009 in direction 0 computed.
# route 254 in direction 1 computed.
# route 254 in direction 0 computed.
# route 62391 in direction 1 computed.
# route 62391 in direction 0 computed.
# route 62260 in direction 1 computed.
# route 62260 in direction 0 computed.
# route 1683 in direction 1 computed.
# route 1683 in direction 0 computed.
# route 52893 in direction 1 computed.
# route 52893 in direction 0 computed.
# route 52913 in direction 1 computed.
# route 52913 in direction 0 computed.
# route 54182 in direction 1 computed.
# route 54182 in direction 0 computed.
# route 1133 in direction 1 computed.
# route 1133 in direction 0 computed.
# route 57733 in direction 1 computed.
# route 57733 in direction 0 computed.
# route 57802 in direction 1 computed.
# route 57802 in direction 0 computed.
# route 62734 in direction 1 computed.
# route 62734 in direction 0 computed.
# route 54291 in direction 1 computed.
# route 54291 in direction 0 computed.
# route 32516 in direction 1 computed.
# route 32516 in direction 0 computed.
# route 62283 in direction 1 computed.
# route 62283 in direction 0 computed.
# route 62024 in direction 1 computed.
# route 62024 in direction 0 computed.
# route 61374 in direction 1 computed.
# route 61374 in direction 0 computed.
# route 54215 in direction 1 computed.
# route 54215 in direction 0 computed.
# route 67273 in direction 1 computed.
# route 67273 in direction 0 computed.
# route 61927 in direction 1 computed.
# route 61927 in direction 0 computed.
# route 67053 in direction 1 computed.
# route 67053 in direction 0 computed.
# route 67586 in direction 1 computed.
# route 67586 in direction 0 computed.
# route 62867 in direction 1 computed.
# route 62867 in direction 0 computed.
# route 62604 in direction 1 computed.
# route 62604 in direction 0 computed.
# route 52774 in direction 1 computed.
# route 52774 in direction 0 computed.
# route 66624 in direction 1 computed.
# route 66624 in direction 0 computed.
# route 32555 in direction 1 computed.
# route 32555 in direction 0 computed.
# route 32543 in direction 1 computed.
# route 32543 in direction 0 computed.
# route 62244 in direction 1 computed.
# route 62244 in direction 0 computed.
# route 62402 in direction 1 computed.
# route 62402 in direction 0 computed.
# route 42396 in direction 1 computed.
# route 42396 in direction 0 computed.
# route 65637 in direction 1 computed.
# route 65637 in direction 0 computed.
# route 57771 in direction 1 computed.
# route 57771 in direction 0 computed.
# route 41216 in direction 1 computed.
# route 41216 in direction 0 computed.
# route 67129 in direction 1 computed.
# route 67129 in direction 0 computed.
# route 60678 in direction 1 computed.
# route 60678 in direction 0 computed.
# route 63657 in direction 1 computed.
# route 63657 in direction 0 computed.
# route 246 in direction 1 computed.
# route 246 in direction 0 computed.
# route 62043 in direction 1 computed.
# route 62043 in direction 0 computed.
# route 67606 in direction 1 computed.
# route 67606 in direction 0 computed.
# route 67046 in direction 1 computed.
# route 67046 in direction 0 computed.
# route 59046 in direction 1 computed.
# route 59046 in direction 0 computed.
# route 63665 in direction 1 computed.
# route 63665 in direction 0 computed.
# route 32566 in direction 1 computed.
# route 32566 in direction 0 computed.
# route 62477 in direction 1 computed.
# route 62477 in direction 0 computed.
# route 62058 in direction 1 computed.
# route 62058 in direction 0 computed.
# route 57588 in direction 1 computed.
# route 57588 in direction 0 computed.
# route 62594 in direction 1 computed.
# route 62594 in direction 0 computed.
# route 32536 in direction 1 computed.
# route 32536 in direction 0 computed.
# route 53869 in direction 1 computed.
# route 53869 in direction 0 computed.
# route 52494 in direction 1 computed.
# route 52494 in direction 0 computed.
# route 62481 in direction 1 computed.
# route 62481 in direction 0 computed.
# route 1338 in direction 1 computed.
# route 1338 in direction 0 computed.
# route 57699 in direction 1 computed.
# route 57699 in direction 0 computed.
# route 67049 in direction 1 computed.
# route 67049 in direction 0 computed.
# route 63734 in direction 1 computed.
# route 63734 in direction 0 computed.
# route 52989 in direction 1 computed.
# route 52989 in direction 0 computed.
# route 54301 in direction 1 computed.
# route 54301 in direction 0 computed.
# route 67580 in direction 1 computed.
# route 67580 in direction 0 computed.
# route 32569 in direction 1 computed.
# route 32569 in direction 0 computed.
# route 41497 in direction 1 computed.
# route 41497 in direction 0 computed.
# route 230 in direction 1 computed.
# route 230 in direction 0 computed.
# route 52890 in direction 1 computed.
# route 52890 in direction 0 computed.
# route 66220 in direction 1 computed.
# route 66220 in direction 0 computed.
# route 67120 in direction 1 computed.
# route 67120 in direction 0 computed.
# route 67116 in direction 1 computed.
# route 67116 in direction 0 computed.
# route 62277 in direction 1 computed.
# route 62277 in direction 0 computed.
# route 62286 in direction 1 computed.
# route 62286 in direction 0 computed.
# route 67142 in direction 1 computed.
# route 67142 in direction 0 computed.
# route 52899 in direction 1 computed.
# route 52899 in direction 0 computed.
# route 63661 in direction 1 computed.
# route 63661 in direction 0 computed.
# route 1408 in direction 1 computed.
# route 1408 in direction 0 computed.
# route 17792 in direction 1 computed.
# route 17792 in direction 0 computed.
# route 45368 in direction 1 computed.
# route 45368 in direction 0 computed.
# route 67118 in direction 1 computed.
# route 67118 in direction 0 computed.
# route 35202 in direction 1 computed.
# route 35202 in direction 0 computed.
# route 17795 in direction 1 computed.
# route 17795 in direction 0 computed.
# route 58911 in direction 1 computed.
# route 58911 in direction 0 computed.
# route 63700 in direction 1 computed.
# route 63700 in direction 0 computed.
# route 52894 in direction 1 computed.
# route 52894 in direction 0 computed.
# route 67282 in direction 1 computed.
# route 67282 in direction 0 computed.
# route 67583 in direction 1 computed.
# route 67583 in direction 0 computed.
# route 62479 in direction 1 computed.
# route 62479 in direction 0 computed.
# route 67296 in direction 1 computed.
# route 67296 in direction 0 computed.
# route 32511 in direction 1 computed.
# route 32511 in direction 0 computed.
# route 17309 in direction 1 computed.
# route 17309 in direction 0 computed.
# route 53837 in direction 1 computed.
# route 53837 in direction 0 computed.
# route 62262 in direction 1 computed.
# route 62262 in direction 0 computed.
# route 6384 in direction 1 computed.
# route 6384 in direction 0 computed.
# route 57616 in direction 1 computed.
# route 57616 in direction 0 computed.
# route 67087 in direction 1 computed.
# route 67087 in direction 0 computed.
# route 67245 in direction 1 computed.
# route 67245 in direction 0 computed.
# route 52901 in direction 1 computed.
# route 52901 in direction 0 computed.
# route 54192 in direction 1 computed.
# route 54192 in direction 0 computed.
# route 67293 in direction 1 computed.
# route 67293 in direction 0 computed.
# route 2536 in direction 1 computed.
# route 2536 in direction 0 computed.
# route 53004 in direction 1 computed.
# route 53004 in direction 0 computed.
# route 61305 in direction 1 computed.
# route 61305 in direction 0 computed.
# route 41228 in direction 1 computed.
# route 41228 in direction 0 computed.
# route 67534 in direction 1 computed.
# route 67534 in direction 0 computed.
# route 67244 in direction 1 computed.
# route 67244 in direction 0 computed.
# route 21713 in direction 1 computed.
# route 21713 in direction 0 computed.
# route 52906 in direction 1 computed.
# route 52906 in direction 0 computed.
# route 41869 in direction 1 computed.
# route 41869 in direction 0 computed.
# route 62019 in direction 1 computed.
# route 62019 in direction 0 computed.
# route 48524 in direction 1 computed.
# route 48524 in direction 0 computed.
# route 67306 in direction 1 computed.
# route 67306 in direction 0 computed.
# route 63525 in direction 1 computed.
# route 63525 in direction 0 computed.
# route 57597 in direction 1 computed.
# route 57597 in direction 0 computed.
# route 66916 in direction 1 computed.
# route 66916 in direction 0 computed.
# route 66237 in direction 1 computed.
# route 66237 in direction 0 computed.
# route 67367 in direction 1 computed.
# route 67367 in direction 0 computed.
# route 60799 in direction 1 computed.
# route 60799 in direction 0 computed.
# route 52905 in direction 1 computed.
# route 52905 in direction 0 computed.
# route 62217 in direction 1 computed.
# route 62217 in direction 0 computed.
# route 1190 in direction 1 computed.
# route 1190 in direction 0 computed.
# route 2630 in direction 1 computed.
# route 2630 in direction 0 computed.
# route 52862 in direction 1 computed.
# route 52862 in direction 0 computed.
# route 62248 in direction 1 computed.
# route 62248 in direction 0 computed.
# route 57686 in direction 1 computed.
# route 57686 in direction 0 computed.
# route 24 in direction 1 computed.
# route 24 in direction 0 computed.
# route 66783 in direction 1 computed.
# route 66783 in direction 0 computed.
# route 60898 in direction 1 computed.
# route 60898 in direction 0 computed.
# route 67406 in direction 1 computed.
# route 67406 in direction 0 computed.
# route 60784 in direction 1 computed.
# route 60784 in direction 0 computed.
# route 67096 in direction 1 computed.
# route 67096 in direction 0 computed.
# route 41836 in direction 1 computed.
# route 41836 in direction 0 computed.
# route 66786 in direction 1 computed.
# route 66786 in direction 0 computed.
# route 65475 in direction 1 computed.
# route 65475 in direction 0 computed.
# route 54280 in direction 1 computed.
# route 54280 in direction 0 computed.
# route 45125 in direction 1 computed.
# route 45125 in direction 0 computed.
# route 67294 in direction 1 computed.
# route 67294 in direction 0 computed.
# route 52490 in direction 1 computed.
# route 52490 in direction 0 computed.
# route 2562 in direction 1 computed.
# route 2562 in direction 0 computed.
# route 32705 in direction 1 computed.
# route 32705 in direction 0 computed.
# route 60817 in direction 1 computed.
# route 60817 in direction 0 computed.
# route 66222 in direction 1 computed.
# route 66222 in direction 0 computed.
# route 67125 in direction 1 computed.
# route 67125 in direction 0 computed.
# route 67092 in direction 1 computed.
# route 67092 in direction 0 computed.
# route 42987 in direction 1 computed.
# route 42987 in direction 0 computed.
# route 61807 in direction 1 computed.
# route 61807 in direction 0 computed.
# route 53313 in direction 1 computed.
# route 53313 in direction 0 computed.
# route 67011 in direction 1 computed.
# route 67011 in direction 0 computed.
# route 41702 in direction 1 computed.
# route 41702 in direction 0 computed.
# route 257 in direction 1 computed.
# route 257 in direction 0 computed.
# route 62006 in direction 1 computed.
# route 62006 in direction 0 computed.
# route 63666 in direction 1 computed.
# route 63666 in direction 0 computed.
# route 67181 in direction 1 computed.
# route 67181 in direction 0 computed.
# route 2573 in direction 1 computed.
# route 2573 in direction 0 computed.
# route 25380 in direction 1 computed.
# route 25380 in direction 0 computed.
# route 54565 in direction 1 computed.
# route 54565 in direction 0 computed.
# route 1153 in direction 1 computed.
# route 1153 in direction 0 computed.
# route 30493 in direction 1 computed.
# route 30493 in direction 0 computed.
# route 57944 in direction 1 computed.
# route 57944 in direction 0 computed.
# route 42284 in direction 1 computed.
# route 42284 in direction 0 computed.
# route 62082 in direction 1 computed.
# route 62082 in direction 0 computed.
# route 67030 in direction 1 computed.
# route 67030 in direction 0 computed.
# route 31665 in direction 1 computed.
# route 31665 in direction 0 computed.
# route 1278 in direction 1 computed.
# route 1278 in direction 0 computed.
# route 2537 in direction 1 computed.
# route 2537 in direction 0 computed.
# route 67020 in direction 1 computed.
# route 67020 in direction 0 computed.
# route 57626 in direction 1 computed.
# route 57626 in direction 0 computed.
# route 66064 in direction 1 computed.
# route 66064 in direction 0 computed.
# route 54596 in direction 1 computed.
# route 54596 in direction 0 computed.
# route 67158 in direction 1 computed.
# route 67158 in direction 0 computed.
# route 61515 in direction 1 computed.
# route 61515 in direction 0 computed.
# route 1386 in direction 1 computed.
# route 1386 in direction 0 computed.
# route 2636 in direction 1 computed.
# route 2636 in direction 0 computed.
# route 67154 in direction 1 computed.
# route 67154 in direction 0 computed.
# route 66912 in direction 1 computed.
# route 66912 in direction 0 computed.
# route 43027 in direction 1 computed.
# route 43027 in direction 0 computed.
# route 63208 in direction 1 computed.
# route 63208 in direction 0 computed.
# route 67121 in direction 1 computed.
# route 67121 in direction 0 computed.
# route 57591 in direction 1 computed.
# route 57591 in direction 0 computed.
# route 439 in direction 1 computed.
# route 439 in direction 0 computed.
# route 66702 in direction 1 computed.
# route 66702 in direction 0 computed.
# route 60893 in direction 1 computed.
# route 60893 in direction 0 computed.
# route 66483 in direction 1 computed.
# route 66483 in direction 0 computed.
# route 57612 in direction 1 computed.
# route 57612 in direction 0 computed.
# route 2651 in direction 1 computed.
# route 2651 in direction 0 computed.
# route 63655 in direction 1 computed.
# route 63655 in direction 0 computed.
# route 30576 in direction 1 computed.
# route 30576 in direction 0 computed.
# route 67005 in direction 1 computed.
# route 67005 in direction 0 computed.
# route 41703 in direction 1 computed.
# route 41703 in direction 0 computed.
# route 60889 in direction 1 computed.
# route 60889 in direction 0 computed.
# route 32553 in direction 1 computed.
# route 32553 in direction 0 computed.
# route 43163 in direction 1 computed.
# route 43163 in direction 0 computed.
# route 67383 in direction 1 computed.
# route 67383 in direction 0 computed.
# route 460 in direction 1 computed.
# route 460 in direction 0 computed.
# route 19301 in direction 1 computed.
# route 19301 in direction 0 computed.
# route 54248 in direction 1 computed.
# route 54248 in direction 0 computed.
# route 62476 in direction 1 computed.
# route 62476 in direction 0 computed.
# route 19010 in direction 1 computed.
# route 19010 in direction 0 computed.
# route 62062 in direction 1 computed.
# route 62062 in direction 0 computed.
# route 19208 in direction 1 computed.
# route 19208 in direction 0 computed.
# route 57807 in direction 1 computed.
# route 57807 in direction 0 computed.
# route 53315 in direction 1 computed.
# route 53315 in direction 0 computed.
# route 62207 in direction 1 computed.
# route 62207 in direction 0 computed.
# route 41729 in direction 1 computed.
# route 41729 in direction 0 computed.
# route 41714 in direction 1 computed.
# route 41714 in direction 0 computed.
# route 67093 in direction 1 computed.
# route 67093 in direction 0 computed.
# route 63685 in direction 1 computed.
# route 63685 in direction 0 computed.
# route 41463 in direction 1 computed.
# route 41463 in direction 0 computed.
# route 2617 in direction 1 computed.
# route 2617 in direction 0 computed.
# route 66726 in direction 1 computed.
# route 66726 in direction 0 computed.
# route 5444 in direction 1 computed.
# route 5444 in direction 0 computed.
# route 53838 in direction 1 computed.
# route 53838 in direction 0 computed.
# route 62009 in direction 1 computed.
# route 62009 in direction 0 computed.
# route 60896 in direction 1 computed.
# route 60896 in direction 0 computed.
# route 67375 in direction 1 computed.
# route 67375 in direction 0 computed.
# route 57768 in direction 1 computed.
# route 57768 in direction 0 computed.
# route 41713 in direction 1 computed.
# route 41713 in direction 0 computed.
# route 67223 in direction 1 computed.
# route 67223 in direction 0 computed.
# route 32570 in direction 1 computed.
# route 32570 in direction 0 computed.
# route 32535 in direction 1 computed.
# route 32535 in direction 0 computed.
# route 63678 in direction 1 computed.
# route 63678 in direction 0 computed.
# route 42421 in direction 1 computed.
# route 42421 in direction 0 computed.
# route 54196 in direction 1 computed.
# route 54196 in direction 0 computed.
# route 41837 in direction 1 computed.
# route 41837 in direction 0 computed.
# route 45094 in direction 1 computed.
# route 45094 in direction 0 computed.
# route 45132 in direction 1 computed.
# route 45132 in direction 0 computed.
# route 61920 in direction 1 computed.
# route 61920 in direction 0 computed.
# route 41495 in direction 1 computed.
# route 41495 in direction 0 computed.
# route 41723 in direction 1 computed.
# route 41723 in direction 0 computed.
# route 30800 in direction 1 computed.
# route 30800 in direction 0 computed.
# route 66763 in direction 1 computed.
# route 66763 in direction 0 computed.
# route 54198 in direction 1 computed.
# route 54198 in direction 0 computed.
# route 45366 in direction 1 computed.
# route 45366 in direction 0 computed.
# route 45121 in direction 1 computed.
# route 45121 in direction 0 computed.
# route 67027 in direction 1 computed.
# route 67027 in direction 0 computed.
# route 63395 in direction 1 computed.
# route 63395 in direction 0 computed.
# route 67225 in direction 1 computed.
# route 67225 in direction 0 computed.
# route 66250 in direction 1 computed.
# route 66250 in direction 0 computed.
# route 42267 in direction 1 computed.
# route 42267 in direction 0 computed.
# route 67280 in direction 1 computed.
# route 67280 in direction 0 computed.
# route 67435 in direction 1 computed.
# route 67435 in direction 0 computed.
# route 54149 in direction 1 computed.
# route 54149 in direction 0 computed.
# route 61793 in direction 1 computed.
# route 61793 in direction 0 computed.
# route 67024 in direction 1 computed.
# route 67024 in direction 0 computed.
# route 41721 in direction 1 computed.
# route 41721 in direction 0 computed.
# route 57740 in direction 1 computed.
# route 57740 in direction 0 computed.
# route 25377 in direction 1 computed.
# route 25377 in direction 0 computed.
# route 53335 in direction 1 computed.
# route 53335 in direction 0 computed.
# route 256 in direction 1 computed.
# route 256 in direction 0 computed.
# route 54143 in direction 1 computed.
# route 54143 in direction 0 computed.
# route 30582 in direction 1 computed.
# route 30582 in direction 0 computed.
# route 53535 in direction 1 computed.
# route 53535 in direction 0 computed.
# route 61993 in direction 1 computed.
# route 61993 in direction 0 computed.
# route 67287 in direction 1 computed.
# route 67287 in direction 0 computed.
# route 52856 in direction 1 computed.
# route 52856 in direction 0 computed.
# route 1069 in direction 1 computed.
# route 1069 in direction 0 computed.
# route 41728 in direction 1 computed.
# route 41728 in direction 0 computed.
# route 67376 in direction 1 computed.
# route 67376 in direction 0 computed.
# route 61788 in direction 1 computed.
# route 61788 in direction 0 computed.
# route 67110 in direction 1 computed.
# route 67110 in direction 0 computed.
# route 63682 in direction 1 computed.
# route 63682 in direction 0 computed.
# route 41738 in direction 1 computed.
# route 41738 in direction 0 computed.
# route 66821 in direction 1 computed.
# route 66821 in direction 0 computed.
# route 54218 in direction 1 computed.
# route 54218 in direction 0 computed.
# route 41214 in direction 1 computed.
# route 41214 in direction 0 computed.
# route 66701 in direction 1 computed.
# route 66701 in direction 0 computed.
# route 67224 in direction 1 computed.
# route 67224 in direction 0 computed.
# route 61373 in direction 1 computed.
# route 61373 in direction 0 computed.
# route 480 in direction 1 computed.
# route 480 in direction 0 computed.
# route 41706 in direction 1 computed.
# route 41706 in direction 0 computed.
# route 62393 in direction 1 computed.
# route 62393 in direction 0 computed.
# route 1101 in direction 1 computed.
# route 1101 in direction 0 computed.
# route 65697 in direction 1 computed.
# route 65697 in direction 0 computed.
# route 67250 in direction 1 computed.
# route 67250 in direction 0 computed.
# route 61992 in direction 1 computed.
# route 61992 in direction 0 computed.
# route 65615 in direction 1 computed.
# route 65615 in direction 0 computed.
# route 60661 in direction 1 computed.
# route 60661 in direction 0 computed.
# route 46084 in direction 1 computed.
# route 46084 in direction 0 computed.
# route 66811 in direction 1 computed.
# route 66811 in direction 0 computed.
# route 2511 in direction 1 computed.
# route 2511 in direction 0 computed.
# route 66735 in direction 1 computed.
# route 66735 in direction 0 computed.
# route 54147 in direction 1 computed.
# route 54147 in direction 0 computed.
# route 43042 in direction 1 computed.
# route 43042 in direction 0 computed.
# route 43049 in direction 1 computed.
# route 43049 in direction 0 computed.
# route 66753 in direction 1 computed.
# route 66753 in direction 0 computed.
# route 43020 in direction 1 computed.
# route 43020 in direction 0 computed.
# route 52851 in direction 1 computed.
# route 52851 in direction 0 computed.
# route 57682 in direction 1 computed.
# route 57682 in direction 0 computed.
# route 67531 in direction 1 computed.
# route 67531 in direction 0 computed.
# route 67061 in direction 1 computed.
# route 67061 in direction 0 computed.
# route 65789 in direction 1 computed.
# route 65789 in direction 0 computed.
# route 41206 in direction 1 computed.
# route 41206 in direction 0 computed.
# route 63633 in direction 1 computed.
# route 63633 in direction 0 computed.
# route 66815 in direction 1 computed.
# route 66815 in direction 0 computed.
# route 45103 in direction 1 computed.
# route 45103 in direction 0 computed.
# route 32560 in direction 1 computed.
# route 32560 in direction 0 computed.
# route 25388 in direction 1 computed.
# route 25388 in direction 0 computed.
# route 61941 in direction 1 computed.
# route 61941 in direction 0 computed.
# route 41198 in direction 1 computed.
# route 41198 in direction 0 computed.
# route 33048 in direction 1 computed.
# route 33048 in direction 0 computed.
# route 62038 in direction 1 computed.
# route 62038 in direction 0 computed.
# route 66781 in direction 1 computed.
# route 66781 in direction 0 computed.
# route 32512 in direction 1 computed.
# route 32512 in direction 0 computed.
# route 32513 in direction 1 computed.
# route 32513 in direction 0 computed.
# route 6380 in direction 1 computed.
# route 6380 in direction 0 computed.
# route 47993 in direction 1 computed.
# route 47993 in direction 0 computed.
# route 60887 in direction 1 computed.
# route 60887 in direction 0 computed.
# route 66994 in direction 1 computed.
# route 66994 in direction 0 computed.
# route 1335 in direction 1 computed.
# route 1335 in direction 0 computed.
# route 6737 in direction 1 computed.
# route 6737 in direction 0 computed.
# route 52850 in direction 1 computed.
# route 52850 in direction 0 computed.
# route 61932 in direction 1 computed.
# route 61932 in direction 0 computed.
# route 19218 in direction 1 computed.
# route 19218 in direction 0 computed.
# route 1616 in direction 1 computed.
# route 1616 in direction 0 computed.
# route 61038 in direction 1 computed.
# route 61038 in direction 0 computed.
# route 54282 in direction 1 computed.
# route 54282 in direction 0 computed.
# route 1228 in direction 1 computed.
# route 1228 in direction 0 computed.
# route 1339 in direction 1 computed.
# route 1339 in direction 0 computed.
# route 67179 in direction 1 computed.
# route 67179 in direction 0 computed.
# route 30574 in direction 1 computed.
# route 30574 in direction 0 computed.
# route 41717 in direction 1 computed.
# route 41717 in direction 0 computed.
# route 57720 in direction 1 computed.
# route 57720 in direction 0 computed.
# route 62405 in direction 1 computed.
# route 62405 in direction 0 computed.
# route 62514 in direction 1 computed.
# route 62514 in direction 0 computed.
# route 16 in direction 1 computed.
# route 16 in direction 0 computed.
# route 67291 in direction 1 computed.
# route 67291 in direction 0 computed.
# route 41208 in direction 1 computed.
# route 41208 in direction 0 computed.
# route 1646 in direction 1 computed.
# route 1646 in direction 0 computed.
# route 41478 in direction 1 computed.
# route 41478 in direction 0 computed.
# route 57753 in direction 1 computed.
# route 57753 in direction 0 computed.
# route 41674 in direction 1 computed.
# route 41674 in direction 0 computed.
# route 67094 in direction 1 computed.
# route 67094 in direction 0 computed.
# route 2576 in direction 1 computed.
# route 2576 in direction 0 computed.
# route 45105 in direction 1 computed.
# route 45105 in direction 0 computed.
# route 30495 in direction 1 computed.
# route 30495 in direction 0 computed.
# route 1486 in direction 1 computed.
# route 1486 in direction 0 computed.
# route 30633 in direction 1 computed.
# route 30633 in direction 0 computed.
# route 41711 in direction 1 computed.
# route 41711 in direction 0 computed.
# route 63412 in direction 1 computed.
# route 63412 in direction 0 computed.
# route 66581 in direction 1 computed.
# route 66581 in direction 0 computed.
# route 54165 in direction 1 computed.
# route 54165 in direction 0 computed.
# route 66993 in direction 1 computed.
# route 66993 in direction 0 computed.
# route 67449 in direction 1 computed.
# route 67449 in direction 0 computed.
# route 66235 in direction 1 computed.
# route 66235 in direction 0 computed.
# route 67299 in direction 1 computed.
# route 67299 in direction 0 computed.
# route 67072 in direction 1 computed.
# route 67072 in direction 0 computed.
# route 41867 in direction 1 computed.
# route 41867 in direction 0 computed.
# route 52888 in direction 1 computed.
# route 52888 in direction 0 computed.
# route 62189 in direction 1 computed.
# route 62189 in direction 0 computed.
# route 54259 in direction 1 computed.
# route 54259 in direction 0 computed.
# route 67255 in direction 1 computed.
# route 67255 in direction 0 computed.
# route 54230 in direction 1 computed.
# route 54230 in direction 0 computed.
# route 4807 in direction 1 computed.
# route 4807 in direction 0 computed.
# route 61330 in direction 1 computed.
# route 61330 in direction 0 computed.
# route 61774 in direction 1 computed.
# route 61774 in direction 0 computed.
# route 1490 in direction 1 computed.
# route 1490 in direction 0 computed.
# route 30498 in direction 1 computed.
# route 30498 in direction 0 computed.
# route 32545 in direction 1 computed.
# route 32545 in direction 0 computed.
# route 62052 in direction 1 computed.
# route 62052 in direction 0 computed.
# route 41839 in direction 1 computed.
# route 41839 in direction 0 computed.
# route 63556 in direction 1 computed.
# route 63556 in direction 0 computed.
# route 2627 in direction 1 computed.
# route 2627 in direction 0 computed.
# route 62394 in direction 1 computed.
# route 62394 in direction 0 computed.
# route 67579 in direction 1 computed.
# route 67579 in direction 0 computed.
# route 63641 in direction 1 computed.
# route 63641 in direction 0 computed.
# route 2607 in direction 1 computed.
# route 2607 in direction 0 computed.
# route 66697 in direction 1 computed.
# route 66697 in direction 0 computed.
# route 32527 in direction 1 computed.
# route 32527 in direction 0 computed.
# route 30586 in direction 1 computed.
# route 30586 in direction 0 computed.
# route 60892 in direction 1 computed.
# route 60892 in direction 0 computed.
# route 57715 in direction 1 computed.
# route 57715 in direction 0 computed.
# route 7175 in direction 1 computed.
# route 7175 in direction 0 computed.
# route 67023 in direction 1 computed.
# route 67023 in direction 0 computed.
# route 25370 in direction 1 computed.
# route 25370 in direction 0 computed.
# route 66384 in direction 1 computed.
# route 66384 in direction 0 computed.
# route 1188 in direction 1 computed.
# route 1188 in direction 0 computed.
# route 61299 in direction 1 computed.
# route 61299 in direction 0 computed.
# route 61768 in direction 1 computed.
# route 61768 in direction 0 computed.
# route 61384 in direction 1 computed.
# route 61384 in direction 0 computed.
# route 41705 in direction 1 computed.
# route 41705 in direction 0 computed.
# route 57735 in direction 1 computed.
# route 57735 in direction 0 computed.
# route 54261 in direction 1 computed.
# route 54261 in direction 0 computed.
# route 32571 in direction 1 computed.
# route 32571 in direction 0 computed.
# route 17305 in direction 1 computed.
# route 17305 in direction 0 computed.
# route 54187 in direction 1 computed.
# route 54187 in direction 0 computed.
# route 5449 in direction 1 computed.
# route 5449 in direction 0 computed.
# route 203 in direction 1 computed.
# route 203 in direction 0 computed.
# route 41731 in direction 1 computed.
# route 41731 in direction 0 computed.
# route 63644 in direction 1 computed.
# route 63644 in direction 0 computed.
# route 66232 in direction 1 computed.
# route 66232 in direction 0 computed.
# route 52907 in direction 1 computed.
# route 52907 in direction 0 computed.
# route 66817 in direction 1 computed.
# route 66817 in direction 0 computed.
# route 429 in direction 1 computed.
# route 429 in direction 0 computed.
# route 471 in direction 1 computed.
# route 471 in direction 0 computed.
# route 60813 in direction 1 computed.
# route 60813 in direction 0 computed.
# route 61973 in direction 1 computed.
# route 61973 in direction 0 computed.
# route 62390 in direction 1 computed.
# route 62390 in direction 0 computed.
# route 63163 in direction 1 computed.
# route 63163 in direction 0 computed.
# route 10 in direction 1 computed.
# route 10 in direction 0 computed.
# route 67394 in direction 1 computed.
# route 67394 in direction 0 computed.
# route 51587 in direction 1 computed.
# route 51587 in direction 0 computed.
# route 32633 in direction 1 computed.
# route 32633 in direction 0 computed.
# route 17828 in direction 1 computed.
# route 17828 in direction 0 computed.
# route 54277 in direction 1 computed.
# route 54277 in direction 0 computed.
# route 45139 in direction 1 computed.
# route 45139 in direction 0 computed.
# route 63212 in direction 1 computed.
# route 63212 in direction 0 computed.
# route 41863 in direction 1 computed.
# route 41863 in direction 0 computed.
# route 67133 in direction 1 computed.
# route 67133 in direction 0 computed.
# route 60818 in direction 1 computed.
# route 60818 in direction 0 computed.
# route 17514 in direction 1 computed.
# route 17514 in direction 0 computed.
# route 67117 in direction 1 computed.
# route 67117 in direction 0 computed.
# route 61866 in direction 1 computed.
# route 61866 in direction 0 computed.
# route 46093 in direction 1 computed.
# route 46093 in direction 0 computed.
# route 60844 in direction 1 computed.
# route 60844 in direction 0 computed.
# route 17633 in direction 1 computed.
# route 17633 in direction 0 computed.
# route 62515 in direction 1 computed.
# route 62515 in direction 0 computed.
# route 62081 in direction 1 computed.
# route 62081 in direction 0 computed.
# route 67128 in direction 1 computed.
# route 67128 in direction 0 computed.
# route 63642 in direction 1 computed.
# route 63642 in direction 0 computed.
# route 67272 in direction 1 computed.
# route 67272 in direction 0 computed.
# route 1214 in direction 1 computed.
# route 1214 in direction 0 computed.
# route 1589 in direction 1 computed.
# route 1589 in direction 0 computed.
# route 18985 in direction 1 computed.
# route 18985 in direction 0 computed.
# route 30569 in direction 1 computed.
# route 30569 in direction 0 computed.
# route 62398 in direction 1 computed.
# route 62398 in direction 0 computed.
# route 60845 in direction 1 computed.
# route 60845 in direction 0 computed.
# route 52881 in direction 1 computed.
# route 52881 in direction 0 computed.
# route 65793 in direction 1 computed.
# route 65793 in direction 0 computed.
# route 54146 in direction 1 computed.
# route 54146 in direction 0 computed.
# route 43026 in direction 1 computed.
# route 43026 in direction 0 computed.
# route 17773 in direction 1 computed.
# route 17773 in direction 0 computed.
# route 61303 in direction 1 computed.
# route 61303 in direction 0 computed.
# route 67505 in direction 1 computed.
# route 67505 in direction 0 computed.
# route 1203 in direction 1 computed.
# route 1203 in direction 0 computed.
# route 61914 in direction 1 computed.
# route 61914 in direction 0 computed.
# route 7450 in direction 1 computed.
# route 7450 in direction 0 computed.
# route 418 in direction 1 computed.
# route 418 in direction 0 computed.
# route 66252 in direction 1 computed.
# route 66252 in direction 0 computed.
# route 54174 in direction 1 computed.
# route 54174 in direction 0 computed.
# route 1596 in direction 1 computed.
# route 1596 in direction 0 computed.
# route 67385 in direction 1 computed.
# route 67385 in direction 0 computed.
# route 67010 in direction 1 computed.
# route 67010 in direction 0 computed.
# route 57697 in direction 1 computed.
# route 57697 in direction 0 computed.
# route 61301 in direction 1 computed.
# route 61301 in direction 0 computed.
# route 57766 in direction 1 computed.
# route 57766 in direction 0 computed.
# route 63635 in direction 1 computed.
# route 63635 in direction 0 computed.
# route 62084 in direction 1 computed.
# route 62084 in direction 0 computed.
# route 409 in direction 1 computed.
# route 409 in direction 0 computed.
# route 53846 in direction 1 computed.
# route 53846 in direction 0 computed.
# route 62401 in direction 1 computed.
# route 62401 in direction 0 computed.
# route 52895 in direction 1 computed.
# route 52895 in direction 0 computed.
# route 57608 in direction 1 computed.
# route 57608 in direction 0 computed.
# route 2574 in direction 1 computed.
# ...
# route 62584 in direction 0 computed.
# route 62860 in direction 1 computed.
# route 62860 in direction 0 computed.
# route 62723 in direction 1 computed.
# route 62723 in direction 0 computed.
# route 61961 in direction 1 computed.
# route 61961 in direction 0 computed.
# route 62665 in direction 1 computed.
# route 62665 in direction 0 computed.
# route 62824 in direction 1 computed.
# route 62824 in direction 0 computed.
# route 62740 in direction 1 computed.
# route 62740 in direction 0 computed.
# route 62848 in direction 1 computed.
# route 62848 in direction 0 computed.
# route 62606 in direction 1 computed.
# route 62606 in direction 0 computed.
# route 62033 in direction 1 computed.
# route 62033 in direction 0 computed.
# route 42253 in direction 1 computed.
# route 42253 in direction 0 computed.
# route 60792 in direction 1 computed.
# route 60792 in direction 0 computed.
# route 66249 in direction 1 computed.
# route 66249 in direction 0 computed.
# route 59898 in direction 1 computed.
# route 59898 in direction 0 computed.
# route 19411 in direction 1 computed.
# route 19411 in direction 0 computed.
# route 50055 in direction 1 computed.
# route 50055 in direction 0 computed.
# route 62819 in direction 1 computed.
# route 62819 in direction 0 computed.
# route 62703 in direction 1 computed.
# route 62703 in direction 0 computed.
# route 62816 in direction 1 computed.
# route 62816 in direction 0 computed.
# route 62841 in direction 1 computed.
# route 62841 in direction 0 computed.
# route 62587 in direction 1 computed.
# route 62587 in direction 0 computed.
# route 62716 in direction 1 computed.
# route 62716 in direction 0 computed.
# route 62739 in direction 1 computed.
# route 62739 in direction 0 computed.
# route 62890 in direction 1 computed.
# route 62890 in direction 0 computed.
# route 62763 in direction 1 computed.
# route 62763 in direction 0 computed.
# route 62602 in direction 1 computed.
# route 62602 in direction 0 computed.
# route 62872 in direction 1 computed.
# route 62872 in direction 0 computed.
# route 62608 in direction 1 computed.
# route 62608 in direction 0 computed.
# route 62636 in direction 1 computed.
# route 62636 in direction 0 computed.
# route 62793 in direction 1 computed.
# route 62793 in direction 0 computed.
# route 62658 in direction 1 computed.
# route 62658 in direction 0 computed.
# route 62902 in direction 1 computed.
# route 62902 in direction 0 computed.
# route 61227 in direction 1 computed.
# route 61227 in direction 0 computed.
# route 62847 in direction 1 computed.
# route 62847 in direction 0 computed.
# route 62210 in direction 1 computed.
# route 62210 in direction 0 computed.
# route 66225 in direction 1 computed.
# route 66225 in direction 0 computed.
# route 61366 in direction 1 computed.
# route 61366 in direction 0 computed.
# route 30608 in direction 1 computed.
# route 30608 in direction 0 computed.
# route 62861 in direction 1 computed.
# route 62861 in direction 0 computed.
# route 62624 in direction 1 computed.
# route 62624 in direction 0 computed.
# route 62575 in direction 1 computed.
# route 62575 in direction 0 computed.
# route 62796 in direction 1 computed.
# route 62796 in direction 0 computed.
# route 62613 in direction 1 computed.
# route 62613 in direction 0 computed.
# route 62767 in direction 1 computed.
# route 62767 in direction 0 computed.
# route 504 in direction 1 computed.
# route 504 in direction 0 computed.
# route 54639 in direction 1 computed.
# route 54639 in direction 0 computed.
# route 62724 in direction 1 computed.
# route 62724 in direction 0 computed.
# route 62676 in direction 1 computed.
# route 62676 in direction 0 computed.
# route 62914 in direction 1 computed.
# route 62914 in direction 0 computed.
# route 62751 in direction 1 computed.
# route 62751 in direction 0 computed.
# route 62735 in direction 1 computed.
# route 62735 in direction 0 computed.
# route 62951 in direction 1 computed.
# route 62951 in direction 0 computed.
# route 62877 in direction 1 computed.
# route 62877 in direction 0 computed.
# route 62601 in direction 1 computed.
# route 62601 in direction 0 computed.
# route 61952 in direction 1 computed.
# route 61952 in direction 0 computed.
# route 18931 in direction 1 computed.
# route 18931 in direction 0 computed.
# route 62670 in direction 1 computed.
# route 62670 in direction 0 computed.
# route 61068 in direction 1 computed.
# route 61068 in direction 0 computed.
# route 19412 in direction 1 computed.
# route 19412 in direction 0 computed.
# route 67381 in direction 1 computed.
# route 67381 in direction 0 computed.
# route 62660 in direction 1 computed.
# route 62660 in direction 0 computed.
# route 62677 in direction 1 computed.
# route 62677 in direction 0 computed.
# route 62561 in direction 1 computed.
# route 62561 in direction 0 computed.
# route 62917 in direction 1 computed.
# route 62917 in direction 0 computed.
# route 62646 in direction 1 computed.
# route 62646 in direction 0 computed.
# route 62578 in direction 1 computed.
# route 62578 in direction 0 computed.
# route 62971 in direction 1 computed.
# route 62971 in direction 0 computed.
# route 62948 in direction 1 computed.
# route 62948 in direction 0 computed.
# route 62567 in direction 1 computed.
# route 62567 in direction 0 computed.
# route 62833 in direction 1 computed.
# route 62833 in direction 0 computed.
# route 62835 in direction 1 computed.
# route 62835 in direction 0 computed.
# route 62743 in direction 1 computed.
# route 62743 in direction 0 computed.
# route 62600 in direction 1 computed.
# route 62600 in direction 0 computed.
# route 61766 in direction 1 computed.
# route 61766 in direction 0 computed.
# route 62612 in direction 1 computed.
# route 62612 in direction 0 computed.
# route 62577 in direction 1 computed.
# route 62577 in direction 0 computed.
# route 62647 in direction 1 computed.
# route 62647 in direction 0 computed.
# route 62576 in direction 1 computed.
# route 62576 in direction 0 computed.
# route 62579 in direction 1 computed.
# route 62579 in direction 0 computed.
# route 62627 in direction 1 computed.
# route 62627 in direction 0 computed.
# route 62831 in direction 1 computed.
# route 62831 in direction 0 computed.
# route 62721 in direction 1 computed.
# route 62721 in direction 0 computed.
# route 62722 in direction 1 computed.
# route 62722 in direction 0 computed.
# route 62748 in direction 1 computed.
# route 62748 in direction 0 computed.
# route 62964 in direction 1 computed.
# route 62964 in direction 0 computed.
# route 62855 in direction 1 computed.
# route 62855 in direction 0 computed.
# route 62754 in direction 1 computed.
# route 62754 in direction 0 computed.
# route 62585 in direction 1 computed.
# route 62585 in direction 0 computed.
# route 62975 in direction 1 computed.
# route 62975 in direction 0 computed.
# route 62858 in direction 1 computed.
# route 62858 in direction 0 computed.
# route 62797 in direction 1 computed.
# route 62797 in direction 0 computed.
# route 51637 in direction 1 computed.
# route 51637 in direction 0 computed.
# route 42386 in direction 1 computed.
# route 42386 in direction 0 computed.
# route 1082 in direction 1 computed.
# route 1082 in direction 0 computed.
# route 501 in direction 1 computed.
# route 501 in direction 0 computed.
# route 438 in direction 1 computed.
# route 438 in direction 0 computed.
# route 62697 in direction 1 computed.
# route 62697 in direction 0 computed.
# route 62700 in direction 1 computed.
# route 62700 in direction 0 computed.
# route 62813 in direction 1 computed.
# route 62813 in direction 0 computed.
# route 62701 in direction 1 computed.
# route 62701 in direction 0 computed.
# route 62715 in direction 1 computed.
# route 62715 in direction 0 computed.
# route 62843 in direction 1 computed.
# route 62843 in direction 0 computed.
# route 60655 in direction 1 computed.
# route 60655 in direction 0 computed.
# route 62711 in direction 1 computed.
# route 62711 in direction 0 computed.
# route 62909 in direction 1 computed.
# route 62909 in direction 0 computed.
# route 62780 in direction 1 computed.
# route 62780 in direction 0 computed.
# route 62826 in direction 1 computed.
# route 62826 in direction 0 computed.
# route 62955 in direction 1 computed.
# route 62955 in direction 0 computed.
# route 62802 in direction 1 computed.
# route 62802 in direction 0 computed.
# route 62962 in direction 1 computed.
# route 62962 in direction 0 computed.
# route 62596 in direction 1 computed.
# route 62596 in direction 0 computed.
# route 62746 in direction 1 computed.
# route 62746 in direction 0 computed.
# route 62318 in direction 1 computed.
# route 62318 in direction 0 computed.
# route 62828 in direction 1 computed.
# route 62828 in direction 0 computed.
# route 62825 in direction 1 computed.
# route 62825 in direction 0 computed.
# route 62313 in direction 1 computed.
# route 62313 in direction 0 computed.
# route 60884 in direction 1 computed.
# route 60884 in direction 0 computed.
# route 62554 in direction 1 computed.
# route 62554 in direction 0 computed.
# route 62736 in direction 1 computed.
# route 62736 in direction 0 computed.
# route 62557 in direction 1 computed.
# route 62557 in direction 0 computed.
# route 62696 in direction 1 computed.
# route 62696 in direction 0 computed.
# route 62985 in direction 1 computed.
# route 62985 in direction 0 computed.
# route 61946 in direction 1 computed.
# route 61946 in direction 0 computed.
# route 62864 in direction 1 computed.
# route 62864 in direction 0 computed.
# route 62581 in direction 1 computed.
# route 62581 in direction 0 computed.
# route 62800 in direction 1 computed.
# route 62800 in direction 0 computed.
# route 40788 in direction 1 computed.
# route 40788 in direction 0 computed.
# route 62818 in direction 1 computed.
# route 62818 in direction 0 computed.
# route 62738 in direction 1 computed.
# route 62738 in direction 0 computed.
# route 62821 in direction 1 computed.
# route 62821 in direction 0 computed.
# route 62837 in direction 1 computed.
# route 62837 in direction 0 computed.
# route 62822 in direction 1 computed.
# route 62822 in direction 0 computed.
# route 62559 in direction 1 computed.
# route 62559 in direction 0 computed.
# route 62742 in direction 1 computed.
# route 62742 in direction 0 computed.
# route 62695 in direction 1 computed.
# route 62695 in direction 0 computed.
# route 62757 in direction 1 computed.
# route 62757 in direction 0 computed.
# route 62992 in direction 1 computed.
# route 62992 in direction 0 computed.
# route 61964 in direction 1 computed.
# route 61964 in direction 0 computed.
# route 62753 in direction 1 computed.
# route 62753 in direction 0 computed.
# route 62705 in direction 1 computed.
# route 62705 in direction 0 computed.
# route 62906 in direction 1 computed.
# route 62906 in direction 0 computed.
# route 62685 in direction 1 computed.
# route 62685 in direction 0 computed.
# route 62781 in direction 1 computed.
# route 62781 in direction 0 computed.
# route 32187 in direction 1 computed.
# route 32187 in direction 0 computed.
# route 40272 in direction 1 computed.
# route 40272 in direction 0 computed.
# route 62246 in direction 1 computed.
# route 62246 in direction 0 computed.
# route 62558 in direction 1 computed.
# route 62558 in direction 0 computed.
# route 62717 in direction 1 computed.
# route 62717 in direction 0 computed.
# route 62556 in direction 1 computed.
# route 62556 in direction 0 computed.
# route 62704 in direction 1 computed.
# route 62704 in direction 0 computed.
# route 62615 in direction 1 computed.
# route 62615 in direction 0 computed.
# route 62823 in direction 1 computed.
# route 62823 in direction 0 computed.
# route 62869 in direction 1 computed.
# route 62869 in direction 0 computed.
# route 6145 in direction 1 computed.
# route 6145 in direction 0 computed.
# route 62555 in direction 1 computed.
# route 62555 in direction 0 computed.
# route 61949 in direction 1 computed.
# route 61949 in direction 0 computed.
# route 486 in direction 1 computed.
# route 486 in direction 0 computed.
# route 62907 in direction 1 computed.
# route 62907 in direction 0 computed.
# route 61963 in direction 1 computed.
# route 61963 in direction 0 computed.
# route 491 in direction 1 computed.
# route 491 in direction 0 computed.
# route 502 in direction 1 computed.
# route 502 in direction 0 computed.
# route 62745 in direction 1 computed.
# route 62745 in direction 0 computed.
# route 62580 in direction 1 computed.
# route 62580 in direction 0 computed.
# route 62698 in direction 1 computed.
# route 62698 in direction 0 computed.
# route 62750 in direction 1 computed.
# route 62750 in direction 0 computed.
# route 19418 in direction 1 computed.
# route 19418 in direction 0 computed.
# route 62963 in direction 1 computed.
# route 62963 in direction 0 computed.
# route 62589 in direction 1 computed.
# route 62589 in direction 0 computed.
# route 62801 in direction 1 computed.
# route 62801 in direction 0 computed.
# route 62616 in direction 1 computed.
# route 62616 in direction 0 computed.
# route 62805 in direction 1 computed.
# route 62805 in direction 0 computed.
# route 503 in direction 1 computed.
# route 503 in direction 0 computed.
# route 62741 in direction 1 computed.
# route 62741 in direction 0 computed.
# route 62954 in direction 1 computed.
# route 62954 in direction 0 computed.
# route 62960 in direction 1 computed.
# route 62960 in direction 0 computed.
# route 62686 in direction 1 computed.
# route 62686 in direction 0 computed.
# route 32186 in direction 1 computed.
# route 32186 in direction 0 computed.
# route 19419 in direction 1 computed.
# route 19419 in direction 0 computed.
# route 62712 in direction 1 computed.
# route 62712 in direction 0 computed.
# route 61958 in direction 1 computed.
# route 61958 in direction 0 computed.
# route 67265 in direction 1 computed.
# route 67265 in direction 0 computed.
# route 62699 in direction 1 computed.
# route 62699 in direction 0 computed.
# route 62908 in direction 1 computed.
# route 62908 in direction 0 computed.
#       route_id  direction_id  \
# 0        41726             1
# 1        41726             0
# 2        67002             1
# 3        67002             0
# 4        43157             1
# ...        ...           ...
# 4887     67265             0
# 4888     62699             1
# 4889     62699             0
# 4890     62908             1
# 4891     62908             0
#
#                                              start_time  \
# 0     [05:49:00, 05:55:00, 06:46:00, 06:54:00, 07:23...
# 1     [06:18:00, 06:31:00, 07:01:00, 07:31:00, 08:05...
# 2     [05:58:00, 06:15:00, 07:15:00, 08:17:00, 09:17...
# 3     [05:35:00, 06:35:00, 07:35:00, 08:35:00, 09:35...
# 4                                                   NaN
# ...                                                 ...
# 4887                                         [07:35:00]
# 4888  [07:05:00, 08:05:00, 09:05:00, 10:05:00, 11:05...
# 4889  [06:15:00, 07:05:00, 08:05:00, 09:05:00, 10:05...
# 4890  [09:05:00, 10:05:00, 11:05:00, 12:05:00, 14:05...
# 4891  [09:00:00, 10:00:00, 11:00:00, 12:00:00, 14:00...
#
#                                           stop_sequence  \
# 0     [1479722, 343140, 6639, 480533, 5750, 1480119,...
# 1     [221260, 5520, 1480064, 539293, 6816, 7146, 74...
# 2     [1538515, 1525504, 1240604, 1240569, 650428, 1...
# 3     [649655, 649451, 650033, 649996, 649942, 64982...
# 4                                                   NaN
# ...                                                 ...
# 4887                         [416743, 1692567, 1727875]
# 4888                                 [1421103, 1421222]
# 4889                                 [1421222, 1421103]
# 4890                                    [1421103, 6520]
# 4891                                    [6520, 1421103]
#
#                                           inter_stop_tt
# 0     [120, 60, 120, 120, 360, 240, 60, 120, 60, 180...
# 1     [120, 120, 60, 60, 60, 180, 60, 60, 60, 180, 1...
# 2     [60, 60, 60, 60, 180, 60, 60, 120, 120, 120, 6...
# 3     [120, 120, 60, 60, 60, 60, 120, 60, 120, 120, ...
# 4                                                   NaN
# ...                                                 ...
# 4887                                        [300, 1500]
# 4888                                             [1200]
# 4889                                             [1200]
# 4890                                             [1500]
# 4891                                             [1500]
#
# [4892 rows x 5 columns]

# %%
time_schedule = pd.merge(time_schedule, routes, on="route_id")
time_schedule.head(10)
# Out:
#    route_id  direction_id                                         start_time  \
# 0     41726             1  [05:49:00, 05:55:00, 06:46:00, 06:54:00, 07:23...
# 1     41726             0  [06:18:00, 06:31:00, 07:01:00, 07:31:00, 08:05...
# 2     67002             1  [05:58:00, 06:15:00, 07:15:00, 08:17:00, 09:17...
# 3     67002             0  [05:35:00, 06:35:00, 07:35:00, 08:35:00, 09:35...
# 4     43157             1                                                NaN
# 5     43157             0  [09:25:00, 09:45:00, 10:05:00, 10:25:00, 10:45...
# 6       200             1  [06:13:00, 06:43:00, 07:13:00, 07:43:00, 08:13...
# 7       200             0  [06:00:00, 06:30:00, 07:00:00, 07:30:00, 08:00...
# 8       206             1  [06:16:00, 06:37:00, 06:56:00, 07:16:00, 07:37...
# 9       206             0  [06:00:00, 06:21:00, 06:40:00, 07:00:00, 07:21...
#
#                                        stop_sequence  \
# 0  [1479722, 343140, 6639, 480533, 5750, 1480119,...
# 1  [221260, 5520, 1480064, 539293, 6816, 7146, 74...
# 2  [1538515, 1525504, 1240604, 1240569, 650428, 1...
# 3  [649655, 649451, 650033, 649996, 649942, 64982...
# 4                                                NaN
# 5  [649584, 5912, 6496, 157878, 1927926, 7380, 57...
# 6  [5703, 7286, 109781, 5516, 6843, 6252, 1546702...
# 7  [1961657, 6924, 6738, 5791, 1501652, 5929, 664...
# 8  [548287, 5872, 6206, 109785, 63642, 5511, 5625...
# 9  [827054, 5975, 1479912, 7070, 1533365, 1927900...
#
#                                        inter_stop_tt  route_type
# 0  [120, 60, 120, 120, 360, 240, 60, 120, 60, 180...           3
# 1  [120, 120, 60, 60, 60, 180, 60, 60, 60, 180, 1...           3
# 2  [60, 60, 60, 60, 180, 60, 60, 120, 120, 120, 6...           3
# 3  [120, 120, 60, 60, 60, 60, 120, 60, 120, 120, ...           3
# 4                                                NaN           3
# 5  [180, 60, 0, 60, 0, 60, 0, 60, 0, 60, 60, 60, ...           3
# 6  [0, 60, 0, 60, 60, 60, 60, 0, 60, 60, 60, 60, ...           3
# 7  [120, 60, 0, 60, 60, 0, 60, 60, 0, 120, 60, 60...           3
# 8  [60, 0, 60, 60, 0, 60, 60, 0, 60, 120, 60, 0, ...           3
# 9  [180, 60, 120, 60, 60, 60, 60, 60, 0, 60, 60, ...           3

# %%
print(time_schedule.route_type.unique())
print(time_schedule.shape[0])

#0 - Tram, Streetcar, Light rail. Any light rail or street level system within a metropolitan area.
#1 - Subway, Metro. Any underground rail system within a metropolitan area.
#2 - Rail. Used for intercity or long-distance travel.
#3 - Bus. Used for short- and long-distance bus routes.
#4 - Ferry. Used for short- and long-distance boat service.

# More details at https://developers.google.com/transit/gtfs/reference#tripstxt
# Out:
# [3 0 1 2 4]
# 4892

# %%
folder = '../gtfs_data/netherlands/time_schedules/'
time_schedule.to_csv('{0}{1}.csv'.format(folder,date_text), header=True, index=False)
