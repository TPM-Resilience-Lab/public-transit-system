# %% [markdown]
# # Creating city-level GTFS datasets from region-level GTFS data

# %% [markdown]
# ### Overview
# This notebook contains codes to generate GTFS subset datasets for smaller regions and cities from regional GTFS datasets. For example, this set of codes can be used to derive GTFS datasets of cities like Den Haag, Amsterdam, etc. from the standard Netherlands GTFS dataset provided by OVAPI.

# %% [markdown]
# ### Import required libraries

# %%
import sys
from pathlib import Path
import json
import pandas as pd
import numpy as np
import geopandas as gp
import matplotlib
import gtfs_kit as gk
import os
import zipfile
import bokeh.plotting as bp
from bokeh.models.tiles import WMTSTileSource
import datashader as ds
import datashader.transfer_functions as tf
from datashader.bokeh_ext import InteractiveImage
from datashader.utils import export_image
import colorcet as cc
from datashader.utils import lnglat_to_meters
import numpy as np
from shapely.geometry import Point

import osmnx as ox
ox.config(use_cache=True, log_console=True)

# %% [markdown]
# ### Mandatory user inputs

# %%
#setting GTFS data directory path for loading
DIR = Path('..')
sys.path.append(str(DIR))
DATA_DIR = DIR/'gtfs_data/' #GTFS datasets to be processed must be downloaded or stored here.

#loading GTFS data and list the feed components. You may edit the path variable depending upon where the GTFS dataset is stored.
path = DATA_DIR/'gtfs-openov-nl.zip'
gk.list_feed(path)

#Setting GTFS data details. REGION_NAME attribute is the region covered by the available GTFS dataset. For the openov dataset, it is the Netherlands.
#CITY_NAME is the city of interest. The city must be a subset of the GTFS region. Use the name attribute from the OSM Hague page (https://www.openstreetmap.org/relation/192737)
REGION_NAME = 'netherlands'
CITY_NAME = 'Rotterdam'

# %% [markdown]
# ### Analyzing GTFS data

# %%
#Decompressing the zipped GTFS dataset to individual files. 
#Refer to https://developers.google.com/transit/gtfs for information regarding the GTFS constituent files and attributes.
with zipfile.ZipFile(path, 'r') as file:
    file.extractall(DIR/'gtfs_data/{}/'.format(REGION_NAME))

#List constituent files from the GTFS dataset
os.listdir(DIR/'gtfs_data/{}/'.format(REGION_NAME))
# Out:
# ['agency.txt',
#  'calendar_dates.txt',
#  'feed_info.txt',
#  'routes.txt',
#  'shapes.txt',
#  'stops.txt',
#  'stop_times.txt',
#  'trips.txt']

# %%
#Loading GTFS files as pandas dataframes for viewing and anlysis
trips = pd.read_csv(DIR/'gtfs_data/{}/trips.txt'.format(REGION_NAME), low_memory=False)
shapes = pd.read_csv(DIR/'gtfs_data/{}/shapes.txt'.format(REGION_NAME), low_memory=False)
routes = pd.read_csv(DIR/'gtfs_data/{}/routes.txt'.format(REGION_NAME), low_memory=False)

# %%
trips.head()
# Out:
#    route_id  service_id    trip_id realtime_trip_id     trip_headsign  \
# 0     60663           1  123151939       GVB:248:67        Houthavens
# 1     60663           1  123151940       GVB:248:70        Houthavens
# 2     60663           1  123151932       GVB:248:53        Houthavens
# 3     60663           1  123151991      GVB:248:184  Centraal Station
# 4     60663           1  123151909        GVB:248:6        Houthavens
#
#    trip_short_name trip_long_name  direction_id  block_id  shape_id  \
# 0              NaN            NaN             0       NaN  911191.0
# 1              NaN            NaN             0       NaN  911191.0
# 2              NaN            NaN             0       NaN  911191.0
# 3              NaN            NaN             1       NaN  911190.0
# 4              NaN            NaN             0       NaN  911191.0
#
#    wheelchair_accessible  bikes_allowed
# 0                      1            NaN
# 1                      1            NaN
# 2                      1            NaN
# 3                      1            NaN
# 4                      1            NaN

# %%
shapes.head()
# Out:
#    shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  \
# 0    899197                  1      51.93779       4.33613
# 1    899197                  2      51.93312       4.34160
# 2    899197                  4      51.93318       4.34167
# 3    899197                  5      51.93322       4.34171
# 4    899197                  6      51.93330       4.34192
#
#    shape_dist_traveled
# 0                    0
# 1                 1076
# 2                 1085
# 3                 1090
# 4                 1107

# %%
routes.head()
# Out:
#    route_id agency_id      route_short_name  \
# 0     73358     BRENG                    78
# 1     75937       ARR                     2
# 2     67394    IFF:NS             Intercity
# 3     67395    IFF:NS             Intercity
# 4     67396  IFF:RNET  Stopbus i.p.v. trein
#
#                                      route_long_name  route_desc  route_type  \
# 0                          Papendal - Beekdal Lyceum         NaN           3
# 1     Brunssum/Hoensbroek via Heerlen - Bleijerheide         NaN           3
# 2    Den Haag Centraal <-> Eindhoven Centraal IC1100         NaN           2
# 3  Nachtnettrein Rotterdam Centraal <-> Eindhoven...         NaN           2
# 4    Stopbus i.p.v. trein Dordrecht <-> Geldermalsen         NaN           3
#
#   route_color route_text_color route_url
# 0         NaN              NaN       NaN
# 1         NaN              NaN       NaN
# 2         NaN              NaN       NaN
# 3         NaN              NaN       NaN
# 4         NaN              NaN       NaN

# %%
#List the public transit modes available in the current GTFS dataset
routes.route_type.unique().tolist()

#0 - Tram, Streetcar, Light rail. Any light rail or street level system within a metropolitan area.
#1 - Subway, Metro. Any underground rail system within a metropolitan area.
#2 - Rail. Used for intercity or long-distance travel.
#3 - Bus. Used for short- and long-distance bus routes.
#4 - Ferry. Used for short- and long-distance boat service.

# More details at https://developers.google.com/transit/gtfs/reference#tripstxt
# Out:
# [3, 2, 0, 1, 4]

# %% [markdown]
# ### Generating GTFS datasets for the selected city/subregion

# %%
#Download the desired city map from Openstreetmaps. For now, we use Hague.

# define the place query.
query = {'city': CITY_NAME}

# get the boundaries of the place
gdf = ox.geocode_to_gdf(query)
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
#Create directory for the city to store GTFS files
if not os.path.exists(DIR/'gtfs_data/cities/{}/stops.txt'.format(CITY_NAME)):
    os.makedirs(DIR/'gtfs_data/cities/{}/stops.txt'.format(CITY_NAME))

# %%
#Now we need to identify which all transit stations/stops in the GTFS datasets are located within the city's limits. For that first we load te stops.txt file from the GTFS dataset
stops = pd.read_csv(DIR/'gtfs_data/{}/stops.txt'.format(REGION_NAME), low_memory=False)

# %%
stops.head()
# Out:
#    stop_id  stop_code                   stop_name   stop_lat  stop_lon  \
# 0        1        NaN  Arnhem, Station Presikhaaf  51.987910  5.941563
# 1       10        NaN    Doesburg, Tunnel Angerlo  51.997992  6.129636
# 2     1004        NaN            Warnsveld, GGNet  52.131585  6.249971
# 3     1007        NaN           Rheden, Oranjeweg  52.002476  6.032238
# 4  1013214        NaN               Assen, Triade  52.998037  6.558162
#
#    location_type parent_station stop_timezone  wheelchair_boarding  \
# 0              0            NaN           NaN                  1.0
# 1              0            NaN           NaN                  1.0
# 2              0            NaN           NaN                  1.0
# 3              0            NaN           NaN                  1.0
# 4              0            NaN           NaN                  0.0
#
#   platform_code
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
#filtering transit stations within Hague
subset_stations_list = []
geom = gdf.loc[0, 'geometry']

for index, row in stops.iterrows():
    coords = (stops.stop_lon[index], stops.stop_lat[index])
    if geom.intersects(Point(coords)) == True:
        subset_stations_list.append(stops.stop_id[index])

# %%
len(subset_stations_list)
# Out:
# 1196

# %%
#Creating the stops.txt file for Hague GTFS
subset_stops = stops[stops['stop_id'].isin(subset_stations_list)]
subset_stops.to_csv(DIR/'gtfs_data/cities/{}/stops.txt'.format(CITY_NAME), header=True, index=False, sep=',')
    
subset_stops = pd.read_csv(DIR/'gtfs_data/cities/{}/stops.txt'.format(CITY_NAME), sep=',')
subset_stops.tail()
# Out:
#             stop_id  stop_code                          stop_name   stop_lat  \
# 1191  NL:S:31008146        NaN              Rotterdam, Delfshaven  51.910072
# 1192  NL:S:31008148        NaN            Rotterdam, Marconiplein  51.913576
# 1193  NL:S:31008701        NaN  Rotterdam, Meijersplein / Airport  51.956032
# 1194  NL:S:31008703        NaN                Rotterdam, Blijdorp  51.930806
# 1195  NL:S:31008707        NaN          Rotterdam, Melanchthonweg  51.948491
#
#       stop_lon  location_type parent_station     stop_timezone  \
# 1191  4.445762              1            NaN  Europe/Amsterdam
# 1192  4.432259              1            NaN  Europe/Amsterdam
# 1193  4.462228              1            NaN  Europe/Amsterdam
# 1194  4.457847              1            NaN  Europe/Amsterdam
# 1195  4.464572              1            NaN  Europe/Amsterdam
#
#       wheelchair_boarding platform_code
# 1191                  0.0           NaN
# 1192                  0.0           NaN
# 1193                  0.0           NaN
# 1194                  0.0           NaN
# 1195                  0.0           NaN

# %%
#Creating the stop_times.txt for GTFS of the new city
stop_times = pd.read_csv(DIR/'gtfs_data/{}/stop_times.txt'.format(REGION_NAME), low_memory=False)
stop_times['stop_id'] = stop_times['stop_id'].astype(str)
stop_times.head()
# Out:
#      trip_id  stop_sequence  stop_id stop_headsign arrival_time  \
# 0  123996698             14  2337695           NaN     20:58:03
# 1  123996698              3  2335278           NaN     20:35:11
# 2  123996698              1  2335260           NaN     20:34:00
# 3  123996697             14  2337695           NaN     19:58:03
# 4  123996697              3  2335278           NaN     19:35:11
#
#   departure_time  pickup_type  drop_off_type  timepoint  shape_dist_traveled  \
# 0       20:58:03            0              0          0              18229.0
# 1       20:35:11            0              0          0                847.0
# 2       20:34:00            0              1          1                  0.0
# 3       19:58:03            0              0          0              18229.0
# 4       19:35:11            0              0          0                847.0
#
#    fare_units_traveled
# 0                18229
# 1                  847
# 2                    0
# 3                18229
# 4                  847

# %%
trip_list = stop_times.trip_id.unique()
#trip_list = [125353018]
print(trip_list)
print(len(trip_list))
# Out:
# [123996698 123996697 122482725 ... 125587071 125587097 125587111]
# 930228

# %%
subset_trips_list = []
for index, trip in enumerate(trip_list):
    curr_service = stop_times[stop_times.trip_id == trip]
    
    if curr_service['stop_id'].isin(subset_stops.stop_id).any():
        subset_trips_list.append(trip)

    if index % 500 == 0:
        print(index, len(subset_trips_list))
    
print(len(subset_trips_list))
# Out:
# 0 0
# 500 50
# 1000 58
# 1500 60
# 2000 79
# 2500 116
# 3000 166
# 3500 178
# 4000 192
# 4500 217
# 5000 220
# 5500 240
# 6000 241
# 6500 279
# 7000 292
# 7500 369
# 8000 392
# 8500 417
# 9000 435
# 9500 503
# 10000 511
# 10500 571
# 11000 615
# 11500 631
# 12000 679
# 12500 755
# 13000 765
# 13500 781
# 14000 847
# 14500 871
# 15000 908
# 15500 943
# 16000 945
# 16500 956
# 17000 1029
# 17500 1030
# 18000 1099
# 18500 1119
# 19000 1154
# 19500 1203
# 20000 1256
# 20500 1333
# 21000 1415
# 21500 1417
# 22000 1434
# 22500 1440
# 23000 1486
# 23500 1495
# 24000 1496
# 24500 1509
# 25000 1515
# 25500 1560
# 26000 1618
# 26500 1619
# 27000 1621
# 27500 1688
# 28000 1688
# 28500 1711
# 29000 1778
# 29500 1863
# 30000 1899
# 30500 1908
# 31000 1974
# 31500 2005
# 32000 2046
# 32500 2051
# 33000 2054
# 33500 2063
# 34000 2076
# 34500 2090
# 35000 2094
# 35500 2132
# 36000 2187
# 36500 2194
# 37000 2266
# 37500 2267
# 38000 2287
# 38500 2328
# 39000 2336
# 39500 2342
# 40000 2364
# 40500 2404
# 41000 2474
# 41500 2504
# 42000 2512
# 42500 2609
# 43000 2614
# 43500 2621
# 44000 2635
# 44500 2665
# 45000 2673
# 45500 2720
# 46000 2725
# 46500 2736
# 47000 2767
# 47500 2788
# 48000 2789
# 48500 2790
# 49000 2839
# 49500 2890
# 50000 2933
# 50500 2963
# 51000 3020
# 51500 3027
# 52000 3075
# 52500 3114
# 53000 3121
# 53500 3164
# 54000 3194
# 54500 3279
# 55000 3286
# 55500 3303
# 56000 3366
# 56500 3391
# 57000 3432
# 57500 3439
# 58000 3478
# 58500 3486
# 59000 3543
# 59500 3546
# 60000 3610
# 60500 3631
# 61000 3646
# 61500 3707
# 62000 3765
# 62500 3796
# 63000 3933
# 63500 3955
# 64000 3964
# 64500 3967
# 65000 4016
# 65500 4030
# 66000 4032
# 66500 4039
# 67000 4043
# 67500 4073
# 68000 4148
# 68500 4154
# 69000 4157
# 69500 4223
# 70000 4238
# 70500 4255
# 71000 4261
# 71500 4349
# 72000 4433
# 72500 4442
# 73000 4456
# 73500 4560
# 74000 4563
# 74500 4618
# 75000 4622
# 75500 4643
# 76000 4643
# 76500 4676
# 77000 4680
# 77500 4680
# 78000 4775
# 78500 4785
# 79000 4869
# 79500 4869
# 80000 4883
# 80500 4925
# 81000 4936
# 81500 4937
# 82000 4958
# 740500 45297
# 741000 45343
# 741500 45375
# 742000 45389
# 742500 45418
# 743000 45437
# 743500 45470
# 744000 45501
# 744500 45519
# 745000 45541
# 745500 45595
# 746000 45603
# 746500 45625
# 747000 45643
# 747500 45673
# 748000 45693
# 748500 45700
# 749000 45710
# 749500 45723
# 750000 45745
# 750500 45782
# 751000 45808
# 751500 45831
# 752000 45845
# 752500 45868
# 753000 45898
# 753500 45932
# 754000 45946
# 754500 45960
# 755000 46018
# 755500 46039
# 756000 46051
# 756500 46068
# 757000 46091
# 757500 46117
# 758000 46123
# 758500 46149
# 759000 46170
# 759500 46187
# 760000 46205
# 760500 46267
# 761000 46278
# 761500 46300
# 762000 46315
# 762500 46343
# 763000 46383
# 763500 46412
# 764000 46433
# 764500 46462
# 765000 46521
# 765500 46526
# 766000 46536
# 766500 46552
# 767000 46574
# 767500 46597
# 768000 46608
# 768500 46627
# 769000 46643
# 769500 46657
# 770000 46695
# 770500 46741
# 771000 46762
# 771500 46780
# 772000 46808
# 772500 46837
# 773000 46882
# 773500 46909
# 774000 46930
# 774500 46977
# 775000 47008
# 775500 47011
# 776000 47028
# 776500 47044
# 777000 47060
# 777500 47082
# 778000 47088
# 778500 47106
# 779000 47121
# 779500 47139
# 780000 47189
# 780500 47217
# 781000 47247
# 781500 47260
# 782000 47275
# 782500 47299
# 783000 47340
# 783500 47346
# 784000 47370
# 784500 47432
# 785000 47443
# 785500 47454
# 786000 47481
# 786500 47500
# 787000 47528
# 787500 47537
# 788000 47566
# 788500 47584
# 789000 47593
# 789500 47613
# 790000 47671
# 790500 47685
# 791000 47703
# 791500 47734
# 792000 47752
# 792500 47786
# 793000 47813
# 793500 47837
# 794000 47886
# 794500 47919
# 795000 47923
# 795500 47949
# 796000 47960
# 796500 47977
# 797000 47996
# 797500 48010
# 798000 48026
# 798500 48041
# 799000 48060
# 799500 48102
# 800000 48134
# 800500 48161
# 801000 48172
# 801500 48197
# 802000 48228
# 802500 48264
# 803000 48285
# 803500 48302
# 804000 48367
# 804500 48386
# 805000 48391
# 805500 48409
# 806000 48428
# 806500 48464
# 807000 48479
# 807500 48494
# 808000 48514
# 808500 48532
# 809000 48539
# 809500 48590
# 810000 48613
# 810500 48650
# 811000 48671
# 811500 48699
# 812000 48739
# 812500 48760
# 813000 48777
# 813500 48808
# 814000 48861
# 814500 48866
# 815000 48874
# 815500 48908
# 816000 48928
# 816500 48947
# 817000 48968
# 817500 48982
# 818000 49000
# 818500 49010
# 819000 49037
# 819500 49080
# 820000 49109
# 820500 49121
# 821000 49148
# 821500 49174
# 822000 49212
# 822500 49235
# 823000 49253
# 823500 49312
# 824000 49357
# 824500 49365
# 825000 49376
# 825500 49392
# 826000 49427
# 826500 49450
# 827000 49465
# 827500 49478
# 828000 49504
# 828500 49509
# 829000 49556
# 829500 49571
# 830000 49585
# 830500 49585
# 831000 49610
# 831500 49610
# 832000 49620
# 832500 49642
# 833000 49662
# 833500 49664
# 834000 49674
# 834500 49674
# 929000 51533
# 929500 51539
# 930000 51545
# 51547

# %%
subset_stop_times = stop_times[stop_times['trip_id'].isin(subset_trips_list)]
subset_stop_times.to_csv(DIR/'gtfs_data/cities/{}/stop_times.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_stop_times = pd.read_csv(DIR/'gtfs_data/cities/{}/stop_times.txt'.format(CITY_NAME), sep=',')
subset_stop_times.head()
# Out:
#      trip_id  stop_sequence  stop_id  stop_headsign arrival_time  \
# 0  118921361             47  2296068  Station Noord     17:37:37
# 1  118921361             38  1100763  Station Noord     17:26:42
# 2  118921361             37  1100766  Station Noord     17:26:02
# 3  118921361             35  1100764  Station Noord     17:24:22
# 4  118921361             34  1100760  Station Noord     17:23:01
#
#   departure_time  pickup_type  drop_off_type  timepoint  shape_dist_traveled  \
# 0       17:37:37            1              0          0              30529.0
# 1       17:26:42            0              0          0              27293.0
# 2       17:26:02            0              0          0              27056.0
# 3       17:24:22            0              0          0              26470.0
# 4       17:23:01            0              0          0              25992.0
#
#    fare_units_traveled
# 0                29549
# 1                26387
# 2                26157
# 3                25584
# 4                25116

# %%
#Creating trips.txt for Hague
trips = pd.read_csv(DIR/'gtfs_data/{}/trips.txt'.format(REGION_NAME), low_memory=False)

subset_trips = trips[trips['trip_id'].isin(subset_trips_list)]
subset_trips.to_csv(DIR/'gtfs_data/cities/{}/trips.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_trips = pd.read_csv(DIR/'gtfs_data/cities/{}/trips.txt'.format(CITY_NAME), sep=',')
subset_trips.head()
# Out:
#    route_id  service_id    trip_id realtime_trip_id  \
# 0     32518         542  118921360   RET:601:150266
# 1     32518         542  118921353   RET:601:150253
# 2     32518         542  118921343   RET:601:150239
# 3     75871         542  118920332    RET:15:149287
# 4     75871         542  118920336    RET:15:149293
#
#                 trip_headsign  trip_short_name trip_long_name  direction_id  \
# 0            Delft via Berkel              NaN      Streekbus             0
# 1           Berkel Westpolder              NaN      Streekbus             0
# 2  Rotterdam Noord via Berkel              NaN      Streekbus             1
# 3          Rotterdam Centraal              NaN    Frequentbus             0
# 4          Rotterdam Centraal              NaN    Frequentbus             0
#
#    block_id  shape_id  wheelchair_accessible  bikes_allowed
# 0       NaN  947743.0                      0            NaN
# 1       NaN  947743.0                      0            NaN
# 2       NaN  947744.0                      0            NaN
# 3       NaN  944207.0                      0            NaN
# 4       NaN  944207.0                      0            NaN

# %%
#Creating trips.txt for Hague
calender_dates = pd.read_csv(DIR/'gtfs_data/{}/calendar_dates.txt'.format(REGION_NAME), low_memory=False)

subset_calendar = calender_dates[calender_dates['service_id'].isin(subset_trips.service_id)]
subset_calendar.to_csv(DIR/'gtfs_data/cities/{}/calender_dates.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_calendar = pd.read_csv(DIR/'gtfs_data/cities/{}/calender_dates.txt'.format(CITY_NAME), sep=',')
subset_calendar.head()
# Out:
#    service_id      date  exception_type
# 0           1  20201217               1
# 1           2  20201217               1
# 2           2  20210114               1
# 3           2  20210121               1
# 4           2  20210128               1

# %%
#Creating routes.txt for the selected city
subset_routes_list = subset_trips.route_id.unique()
subset_routes_list[0:10]
# Out:
# array([32518, 75871, 32514, 32512, 75753, 32563, 32566, 73468, 59426,
#        30601], dtype=int64)

# %%
routes = pd.read_csv(DIR/'gtfs_data/{}/routes.txt'.format(REGION_NAME), low_memory=False)
routes.head()
# Out:
#    route_id agency_id      route_short_name  \
# 0     73358     BRENG                    78
# 1     75937       ARR                     2
# 2     67394    IFF:NS             Intercity
# 3     67395    IFF:NS             Intercity
# 4     67396  IFF:RNET  Stopbus i.p.v. trein
#
#                                      route_long_name  route_desc  route_type  \
# 0                          Papendal - Beekdal Lyceum         NaN           3
# 1     Brunssum/Hoensbroek via Heerlen - Bleijerheide         NaN           3
# 2    Den Haag Centraal <-> Eindhoven Centraal IC1100         NaN           2
# 3  Nachtnettrein Rotterdam Centraal <-> Eindhoven...         NaN           2
# 4    Stopbus i.p.v. trein Dordrecht <-> Geldermalsen         NaN           3
#
#   route_color route_text_color route_url
# 0         NaN              NaN       NaN
# 1         NaN              NaN       NaN
# 2         NaN              NaN       NaN
# 3         NaN              NaN       NaN
# 4         NaN              NaN       NaN

# %%
subset_routes = routes[routes['route_id'].isin(subset_routes_list)]
subset_routes.to_csv(DIR/'gtfs_data/cities/{}/routes.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_routes = pd.read_csv(DIR/'gtfs_data/cities/{}/routes.txt'.format(CITY_NAME), sep=',')
subset_routes.head()
# Out:
#    route_id agency_id route_short_name  \
# 0     67394    IFF:NS        Intercity
# 1     67395    IFF:NS        Intercity
# 2     67402    IFF:NS        Intercity
# 3     74390       RET              607
# 4     74389       RET              606
#
#                                      route_long_name  route_desc  route_type  \
# 0    Den Haag Centraal <-> Eindhoven Centraal IC1100         NaN           2
# 1  Nachtnettrein Rotterdam Centraal <-> Eindhoven...         NaN           2
# 2  Nachtnettrein Utrecht Centraal <-> Rotterdam C...         NaN           2
# 3                                   Buurtbus Capelle         NaN           3
# 4                            Buurtbus Kralingse Veer         NaN           3
#
#   route_color route_text_color route_url
# 0         NaN              NaN       NaN
# 1         NaN              NaN       NaN
# 2         NaN              NaN       NaN
# 3         NaN              NaN       NaN
# 4         NaN              NaN       NaN

# %%
#creating agency.txt for hague
subset_agency_list = subset_routes.agency_id.unique()
subset_agency_list[0:10]
# Out:
# array(['IFF:NS', 'RET', 'CXX', 'ARR', 'WATERBUS', 'QBUZZ', 'SYNTUS:UT',
#        'BRAVO:ARR', 'EBS', 'IFF:NSI'], dtype=object)

# %%
agency = pd.read_csv(DIR/'gtfs_data/{}/agency.txt'.format(REGION_NAME), low_memory=False)
agency.head()
# Out:
#    agency_id     agency_name              agency_url  \
# 0      ALLGO  allGo (Keolis)  http://www.allgobus.nl
# 1        ARR          Arriva   https://www.arriva.nl
# 2  BRAVO:ARR  Bravo (Arriva)   http://www.bravo.info
# 3  BRAVO:CXX  Bravo (Hermes)   http://www.bravo.info
# 4      BRENG           Breng     http://www.breng.nl
#
#                   agency_fare_url   agency_timezone     agency_phone
# 0                             NaN  Europe/Amsterdam   003188-0331360
# 1   https://www.arriva.nl/eticket  Europe/Amsterdam  0031900-2022022
# 2   https://www.arriva.nl/eticket  Europe/Amsterdam  0031800-0232545
# 3  https://eticket.connexxion.nl/  Europe/Amsterdam  0031800-0222277
# 4                             NaN  Europe/Amsterdam   003126-2142140

# %%
subset_agency = agency[agency['agency_id'].isin(subset_agency_list)]
subset_agency.to_csv(DIR/'gtfs_data/cities/{}/agency.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_agency = pd.read_csv(DIR/'gtfs_data/cities/{}/agency.txt'.format(CITY_NAME), sep=',')
subset_agency.head()
# Out:
#    agency_id     agency_name                agency_url  \
# 0        ARR          Arriva     https://www.arriva.nl
# 1  BRAVO:ARR  Bravo (Arriva)     http://www.bravo.info
# 2        CXX      Connexxion  http://www.connexxion.nl
# 3        EBS             EBS      http://www.ebs-ov.nl
# 4     IFF:NS              NS          http://www.ns.nl
#
#                   agency_fare_url   agency_timezone     agency_phone
# 0   https://www.arriva.nl/eticket  Europe/Amsterdam  0031900-2022022
# 1   https://www.arriva.nl/eticket  Europe/Amsterdam  0031800-0232545
# 2  https://eticket.connexxion.nl/  Europe/Amsterdam  0031900-2666399
# 3                             NaN  Europe/Amsterdam     0031800-0327
# 4        http://www.ns.nl/eticket  Europe/Amsterdam   003130-7515155

# %%
#Creating shapes.txt for selected city
subset_shapes_list = subset_trips.shape_id.unique()
subset_shapes_list[0:10]
# Out:
# array([947743., 947744., 944207., 947686., 899200., 919692., 945654.,
#        947682., 943343., 919757.])

# %%
shapes = pd.read_csv(DIR/'gtfs_data/{}/shapes.txt'.format(REGION_NAME), low_memory=False)
shapes.head()
# Out:
#    shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  \
# 0    899197                  1      51.93779       4.33613
# 1    899197                  2      51.93312       4.34160
# 2    899197                  4      51.93318       4.34167
# 3    899197                  5      51.93322       4.34171
# 4    899197                  6      51.93330       4.34192
#
#    shape_dist_traveled
# 0                    0
# 1                 1076
# 2                 1085
# 3                 1090
# 4                 1107

# %%
subset_shapes = shapes[shapes['shape_id'].isin(subset_shapes_list)]
subset_shapes.to_csv(DIR/'gtfs_data/cities/{}/shapes.txt'.format(CITY_NAME), header=True, index=False, sep=',')

subset_shapes = pd.read_csv(DIR/'gtfs_data/cities/{}/shapes.txt'.format(CITY_NAME), sep=',')
subset_shapes.head()
# Out:
#    shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  \
# 0    899200                  1      51.91355       4.43175
# 1    899200                  2      51.91366       4.43191
# 2    899200                  3      51.91354       4.43208
# 3    899200                  4      51.91343       4.43193
# 4    899200                  5      51.91333       4.43178
#
#    shape_dist_traveled
# 0                    0
# 1                   16
# 2                   34
# 3                   50
# 4                   65
