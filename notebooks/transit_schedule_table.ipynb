# %% [markdown]
# # Time schedule tables from GTFS dataset

# %% [markdown]
# ### Overview
# This notebook contains codes for processing standard GTFS dataset and create approximate time schedule tables for various transit lines in the network.  Each time schedule table provides the start times and stop sequences of transit services on each route. The time schedule tables are generated for a typical weekday, Saturday, and Sunday of every month.

# %% [markdown]
# ### Import required libraries

# %%
import sys
from pathlib import Path
import json
import os

import pandas as pd
import gtfs_kit as gk
import itertools
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from datetime import datetime

# %% [markdown]
# ### Mandatory user inputs
# The mandatory inputs include details such as working directory, region name, and date of release of the GTFS dataset. The typical days are selected manually and must be provided as user input in the codes. The days must be selected such that they are not immediately following or followed by public holdays. Immediate dates of FIL_DATE are used as later days may be missing some of the\ actual trips due to delay in scheduling (this process will be automated in the near future).

# %%
#setting GTFS data directory path for loading
DIR = Path('..')
sys.path.append(str(DIR))
DATA_DIR = DIR/'gtfs_data/' #GTFS datasets to be processed must be downloaded or stored here.

#Setting GTFS data details. REGION_NAME attribute is the region covered by the available GTFS dataset. For the openov dataset, it is the Netherlands.
REGION_NAME = 'netherlands'

#Set the date of the GTFS file.Please rename the GTFS folder with this FIL_DATE
FIL_DATE = '20210104'

#list of typical weekday, Saturday and Sunday. Input the list of dates used for generating the weekday, 
#saturday, and sunday time schedule tables (YYYYMMDD format). 
day_list = {
    "weekday": "20210121",
    "saturday": "20210123",
    "sunday": "20210124" 
}

# %% [markdown]
# ### Settings for saving the time schedule tables

# %%
#dictionary to convert month in #MM format to names
months = {
    "01": "Jan", "02": "Feb", "03": "Mar", "04": "Apr", "05": "May", "06": "Jun",
    "07": "Jul", "08": "Aug", "09": "Sept", "10": "Oct", "11": "Nov", "12": "Dec"
}

#Extract year and month information
year = FIL_DATE[0:4]
month = FIL_DATE[4:6]

month_year_text = '{0}{1}_'.format(months[month],year)

# %%
#Create the 'time_schedules' folder within the gtfs unzipped folder
if not os.path.exists('{0}/{1}/{2}/time_schedules/'.format(DATA_DIR, REGION_NAME, FIL_DATE)):
    os.makedirs('{0}/{1}/{2}/time_schedules/'.format(DATA_DIR, REGION_NAME, FIL_DATE))

# %% [markdown]
# ### Create the time schedule tables

# %%
#Create the time schedule tables for weekday, saturday and sunday.
for key, curr_date in day_list.items():
    routes = pd.read_csv(DIR/'gtfs_data/{0}/{1}/routes.txt'.format(REGION_NAME, FIL_DATE), low_memory=False)
    routes = routes[['route_id', 'route_type']]
    routes.head()

    calendar_dates = pd.read_csv(DIR/'gtfs_data/{0}/{1}/calendar_dates.txt'.format(REGION_NAME, FIL_DATE), low_memory=False)
    calendar_dates.head()

    #Subsetting services on the calendar date
    services_of_interest = calendar_dates.query('date == {}'.format(curr_date)).service_id.values
    services_of_interest[0:5]

    #Subsetting the trips for the date of interest
    trips = pd.read_csv(DIR/'gtfs_data/{0}/{1}/trips.txt'.format(REGION_NAME, FIL_DATE), low_memory=False)
    trips = trips[['route_id', 'service_id', 'trip_id', 'shape_id', 'direction_id']]
    trips = trips.loc[trips['service_id'].isin(services_of_interest)]
    #print(trips.head())

    trips_of_interest = trips.trip_id.values
    #print(trips_of_interest[0:5])
    
    #Select only those stop_times corresponding to the trips of our interest
    stop_times = pd.read_csv(DIR/'gtfs_data/{0}/{1}/stop_times.txt'.format(REGION_NAME, FIL_DATE), low_memory=False)
    stop_times = stop_times.loc[stop_times['trip_id'].isin(trips_of_interest)]
    stop_times['stop_id'] = stop_times['stop_id'].astype(str)
    
    #Delete any wrong entries in stop times (change the range if any timestamp starts with a number >=50)
    stop_times = stop_times[['trip_id', 'stop_sequence', 'stop_id', 'arrival_time', 'departure_time']]
    for string in range(24, 50):
        stop_times = stop_times[~stop_times.arrival_time.str.startswith("{}:".format(string))]
    stop_times.head()
    
    #merge stop times dataframe with trips dataframe
    stop_times = pd.merge(stop_times, trips, on="trip_id")
    stop_times['arrival_time'] = pd.to_datetime(stop_times['arrival_time'],format= '%H:%M:%S' ).dt.time
    stop_times.head()
    
    #Create an empty dataframe with every combination og unique values of route_id and direction_id
    route_list = stop_times.route_id.unique()
    direction_list = stop_times.direction_id.unique()

    cat = {
        'route_id': route_list,
        'direction_id' : direction_list
    }

    order = cat.keys()
    time_schedule = pd.DataFrame(itertools.product(*[cat[k] for k in order]), columns=order)
    time_schedule['start_time'] = np.nan
    time_schedule['stop_sequence'] = np.nan
    time_schedule['inter_stop_tt'] = np.nan

    #time_schedule.head()

    #generate the time schedule details for every route_id and direction_id pair
    for i in range(time_schedule.shape[0]):
        curr_route_stop_times = stop_times.query('route_id == {0} and direction_id == {1} and stop_sequence == 1'.format(time_schedule.route_id[i], time_schedule.direction_id[i]))
        curr_route_stop_times = curr_route_stop_times.reset_index()
        #print(curr_route_stop_times.head())

        if curr_route_stop_times.shape[0] > 0:
            start_times = curr_route_stop_times.arrival_time.sort_values().astype(str)
            start_array = [','.join(ele.split()) for ele in start_times]
            time_schedule.start_time[i] = start_array
            #print(i)

            #adding time intervals between stops
            first_trip_in_curr_route = stop_times.query('trip_id == {}'.format(curr_route_stop_times.trip_id[0]))
            first_trip_in_curr_route = first_trip_in_curr_route.sort_values('stop_sequence')
            #print(first_trip_in_curr_route.head())

            travel_times = pd.to_timedelta(first_trip_in_curr_route['arrival_time'].astype(str)).diff(-1).dt.total_seconds()
            #print(travel_times)
            tt_array = [','.join(ele.split()) for ele in abs(travel_times[:-1]).astype(int).astype(str)]
            time_schedule.inter_stop_tt[i] = tt_array

            stop_sequence = first_trip_in_curr_route.stop_id.astype(str)
            stop_array = [','.join(ele.split()) for ele in stop_sequence]
            time_schedule.stop_sequence[i] = stop_array
        print('route {} in direction {} computed.'.format(time_schedule.route_id[i],time_schedule.direction_id[i]))

    time_schedule = pd.merge(time_schedule, routes, on="route_id")
    time_schedule.head(10)

    #0 - Tram, Streetcar, Light rail. Any light rail or street level system within a metropolitan area.
    #1 - Subway, Metro. Any underground rail system within a metropolitan area.
    #2 - Rail. Used for intercity or long-distance travel.
    #3 - Bus. Used for short- and long-distance bus routes.
    #4 - Ferry. Used for short- and long-distance boat service.

    # More details at https://developers.google.com/transit/gtfs/reference#tripstxt
    
    #save the time schedule table
    folder = '../gtfs_data/{0}/{1}/time_schedules/'.format(REGION_NAME, FIL_DATE)
    time_schedule.to_csv('{0}{1}{2}.csv'.format(folder,month_year_text,key), header=True, index=False) 
    print("Successfully extracted the time schedule table for {0}-{1}".format(key, curr_date))
# Out:
#     route_id  service_id    trip_id  shape_id  direction_id
# 19     19413        1337  121558792  938938.0             0
# 20     19412        1337  121558814  938942.0             0
# 21     19412        1337  121558813  938941.0             1
# 22     19411        1337  121558801  938939.0             1
# 23     19413        1337  121558797  938937.0             1
# [121558792 121558814 121558813 121558801 121558797]
# route 19413 in direction 0 computed.
# route 19413 in direction 1 computed.
# route 61959 in direction 0 computed.
# route 61959 in direction 1 computed.
# route 73441 in direction 0 computed.
# route 73441 in direction 1 computed.
# route 73442 in direction 0 computed.
# route 73442 in direction 1 computed.
# route 73443 in direction 0 computed.
# route 73443 in direction 1 computed.
# route 73444 in direction 0 computed.
# route 73444 in direction 1 computed.
# route 76001 in direction 0 computed.
# route 76001 in direction 1 computed.
# route 76003 in direction 0 computed.
# route 76003 in direction 1 computed.
# route 73452 in direction 0 computed.
# route 73452 in direction 1 computed.
# route 73455 in direction 0 computed.
# route 73455 in direction 1 computed.
# route 73456 in direction 0 computed.
# route 73456 in direction 1 computed.
# route 76006 in direction 0 computed.
# route 76006 in direction 1 computed.
# route 73461 in direction 0 computed.
# route 73461 in direction 1 computed.
# route 76007 in direction 0 computed.
# route 76007 in direction 1 computed.
# route 76008 in direction 0 computed.
# route 76008 in direction 1 computed.
# route 76009 in direction 0 computed.
# route 76009 in direction 1 computed.
# route 76010 in direction 0 computed.
# route 76010 in direction 1 computed.
# route 73468 in direction 0 computed.
# route 73468 in direction 1 computed.
# route 73471 in direction 0 computed.
# route 73471 in direction 1 computed.
# route 73472 in direction 0 computed.
# route 73472 in direction 1 computed.
# route 73473 in direction 0 computed.
# route 73473 in direction 1 computed.
# route 60895 in direction 0 computed.
# route 60895 in direction 1 computed.
# route 60886 in direction 0 computed.
# route 60886 in direction 1 computed.
# route 60896 in direction 0 computed.
# route 60896 in direction 1 computed.
# route 62478 in direction 0 computed.
# route 62478 in direction 1 computed.
# route 43163 in direction 0 computed.
# route 43163 in direction 1 computed.
# route 74088 in direction 0 computed.
# route 74088 in direction 1 computed.
# route 60887 in direction 0 computed.
# route 60887 in direction 1 computed.
# route 74090 in direction 0 computed.
# route 74090 in direction 1 computed.
# route 60888 in direction 0 computed.
# route 60888 in direction 1 computed.
# route 60898 in direction 0 computed.
# route 60898 in direction 1 computed.
# route 60885 in direction 0 computed.
# route 60885 in direction 1 computed.
# route 60897 in direction 0 computed.
# route 60897 in direction 1 computed.
# route 60892 in direction 0 computed.
# route 60892 in direction 1 computed.
# route 60889 in direction 0 computed.
# route 60889 in direction 1 computed.
# route 73569 in direction 0 computed.
# route 73569 in direction 1 computed.
# route 60899 in direction 0 computed.
# route 60899 in direction 1 computed.
# route 418 in direction 0 computed.
# route 418 in direction 1 computed.
# route 412 in direction 0 computed.
# route 412 in direction 1 computed.
# route 62475 in direction 0 computed.
# route 62475 in direction 1 computed.
# route 60891 in direction 0 computed.
# route 60891 in direction 1 computed.
# route 409 in direction 0 computed.
# route 409 in direction 1 computed.
# route 71676 in direction 0 computed.
# route 71676 in direction 1 computed.
# route 76137 in direction 0 computed.
# route 76137 in direction 1 computed.
# route 76136 in direction 0 computed.
# route 76136 in direction 1 computed.
# route 68141 in direction 0 computed.
# route 68141 in direction 1 computed.
# route 71304 in direction 0 computed.
# route 71304 in direction 1 computed.
# route 76135 in direction 0 computed.
# route 76135 in direction 1 computed.
# route 76134 in direction 0 computed.
# route 76134 in direction 1 computed.
# route 62399 in direction 0 computed.
# route 62399 in direction 1 computed.
# route 61993 in direction 0 computed.
# route 61993 in direction 1 computed.
# route 61992 in direction 0 computed.
# route 61992 in direction 1 computed.
# route 62400 in direction 0 computed.
# route 62400 in direction 1 computed.
# route 71305 in direction 0 computed.
# route 71305 in direction 1 computed.
# route 62850 in direction 0 computed.
# route 62850 in direction 1 computed.
# route 62856 in direction 0 computed.
# route 62856 in direction 1 computed.
# route 62563 in direction 0 computed.
# route 62563 in direction 1 computed.
# route 65454 in direction 0 computed.
# route 65454 in direction 1 computed.
# route 62764 in direction 0 computed.
# route 62764 in direction 1 computed.
# route 62754 in direction 0 computed.
# route 62754 in direction 1 computed.
# route 62885 in direction 0 computed.
# route 62885 in direction 1 computed.
# route 62883 in direction 0 computed.
# route 62883 in direction 1 computed.
# route 62623 in direction 0 computed.
# route 62623 in direction 1 computed.
# route 62657 in direction 0 computed.
# route 62657 in direction 1 computed.
# route 62790 in direction 0 computed.
# route 62790 in direction 1 computed.
# route 62872 in direction 0 computed.
# route 62872 in direction 1 computed.
# route 62599 in direction 0 computed.
# route 62599 in direction 1 computed.
# route 62595 in direction 0 computed.
# route 62595 in direction 1 computed.
# route 62786 in direction 0 computed.
# route 62786 in direction 1 computed.
# route 62926 in direction 0 computed.
# route 62926 in direction 1 computed.
# route 62727 in direction 0 computed.
# route 62727 in direction 1 computed.
# route 62733 in direction 0 computed.
# route 62733 in direction 1 computed.
# route 62734 in direction 0 computed.
# route 62734 in direction 1 computed.
# route 62810 in direction 0 computed.
# route 62810 in direction 1 computed.
# route 62662 in direction 0 computed.
# route 62662 in direction 1 computed.
# route 62988 in direction 0 computed.
# route 62988 in direction 1 computed.
# route 62646 in direction 0 computed.
# route 62646 in direction 1 computed.
# route 62643 in direction 0 computed.
# route 62643 in direction 1 computed.
# route 62975 in direction 0 computed.
# route 62975 in direction 1 computed.
# route 62709 in direction 0 computed.
# route 62709 in direction 1 computed.
# route 62860 in direction 0 computed.
# route 62860 in direction 1 computed.
# route 62827 in direction 0 computed.
# route 62827 in direction 1 computed.
# route 62862 in direction 0 computed.
# route 62862 in direction 1 computed.
# route 62843 in direction 0 computed.
# route 62843 in direction 1 computed.
# route 62710 in direction 0 computed.
# route 62710 in direction 1 computed.
# route 62718 in direction 0 computed.
# route 62718 in direction 1 computed.
# route 62712 in direction 0 computed.
# route 62712 in direction 1 computed.
# route 62697 in direction 0 computed.
# route 62697 in direction 1 computed.
# route 62812 in direction 0 computed.
# route 62812 in direction 1 computed.
# route 62818 in direction 0 computed.
# route 62818 in direction 1 computed.
# route 62776 in direction 0 computed.
# route 62776 in direction 1 computed.
# route 62785 in direction 0 computed.
# route 62785 in direction 1 computed.
# route 62890 in direction 0 computed.
# route 62890 in direction 1 computed.
# route 62782 in direction 0 computed.
# route 62782 in direction 1 computed.
# route 62802 in direction 0 computed.
# route 62802 in direction 1 computed.
# route 62803 in direction 0 computed.
# route 62803 in direction 1 computed.
# route 62905 in direction 0 computed.
# route 62905 in direction 1 computed.
# route 62573 in direction 0 computed.
# route 62573 in direction 1 computed.
# route 62969 in direction 0 computed.
# route 62969 in direction 1 computed.
# route 62746 in direction 0 computed.
# route 62746 in direction 1 computed.
# route 62731 in direction 0 computed.
# route 62731 in direction 1 computed.
# route 62791 in direction 0 computed.
# route 62791 in direction 1 computed.
# route 62886 in direction 0 computed.
# route 62886 in direction 1 computed.
# route 62912 in direction 0 computed.
# route 62912 in direction 1 computed.
# route 62911 in direction 0 computed.
# route 62911 in direction 1 computed.
# route 62770 in direction 0 computed.
# route 62770 in direction 1 computed.
# route 76227 in direction 0 computed.
# route 76227 in direction 1 computed.
# route 76217 in direction 0 computed.
# route 76217 in direction 1 computed.
# route 76218 in direction 0 computed.
# route 76218 in direction 1 computed.
# route 76220 in direction 0 computed.
# route 76220 in direction 1 computed.
# route 76208 in direction 0 computed.
# route 76208 in direction 1 computed.
# route 76215 in direction 0 computed.
# route 76215 in direction 1 computed.
# route 76219 in direction 0 computed.
# route 76219 in direction 1 computed.
# route 63155 in direction 0 computed.
# route 63155 in direction 1 computed.
# route 63163 in direction 0 computed.
# route 63163 in direction 1 computed.
# route 63410 in direction 0 computed.
# route 63410 in direction 1 computed.
# route 63412 in direction 0 computed.
# route 63412 in direction 1 computed.
# route 76229 in direction 0 computed.
# route 76229 in direction 1 computed.
# route 76230 in direction 0 computed.
# route 76230 in direction 1 computed.
# route 76232 in direction 0 computed.
# route 76232 in direction 1 computed.
# route 65896 in direction 0 computed.
# route 65896 in direction 1 computed.
# route 65637 in direction 0 computed.
# route 65637 in direction 1 computed.
# route 65891 in direction 0 computed.
# route 65891 in direction 1 computed.
# route 65638 in direction 0 computed.
# route 65638 in direction 1 computed.
# route 63413 in direction 0 computed.
# route 63413 in direction 1 computed.
# route 76231 in direction 0 computed.
# route 76231 in direction 1 computed.
# route 63415 in direction 0 computed.
# route 63415 in direction 1 computed.
# route 66238 in direction 0 computed.
# route 66238 in direction 1 computed.
# route 66233 in direction 0 computed.
# route 66233 in direction 1 computed.
# route 72570 in direction 0 computed.
# route 72570 in direction 1 computed.
# route 66244 in direction 0 computed.
# route 66244 in direction 1 computed.
# route 71298 in direction 0 computed.
# route 71298 in direction 1 computed.
# route 66245 in direction 0 computed.
# route 66245 in direction 1 computed.
# route 66252 in direction 0 computed.
# route 66252 in direction 1 computed.
# route 66250 in direction 0 computed.
# route 66250 in direction 1 computed.
# route 72568 in direction 0 computed.
# route 72568 in direction 1 computed.
# route 66230 in direction 0 computed.
# route 66230 in direction 1 computed.
# route 66223 in direction 0 computed.
# route 66223 in direction 1 computed.
# route 72565 in direction 0 computed.
# route 72565 in direction 1 computed.
# route 66237 in direction 0 computed.
# route 66237 in direction 1 computed.
# route 66251 in direction 0 computed.
# route 66251 in direction 1 computed.
# route 66229 in direction 0 computed.
# route 66229 in direction 1 computed.
# route 71300 in direction 0 computed.
# route 71300 in direction 1 computed.
# route 66240 in direction 0 computed.
# route 66240 in direction 1 computed.
# route 66239 in direction 0 computed.
# route 66239 in direction 1 computed.
# route 66242 in direction 0 computed.
# route 66242 in direction 1 computed.
# route 66700 in direction 0 computed.
# route 66700 in direction 1 computed.
# route 54276 in direction 0 computed.
# route 54276 in direction 1 computed.
# route 52774 in direction 0 computed.
# route 52774 in direction 1 computed.
# route 61767 in direction 0 computed.
# route 61767 in direction 1 computed.
# route 66702 in direction 0 computed.
# route 66702 in direction 1 computed.
# route 54311 in direction 0 computed.
# route 54311 in direction 1 computed.
# route 54255 in direction 0 computed.
# route 54255 in direction 1 computed.
# route 54277 in direction 0 computed.
# route 54277 in direction 1 computed.
# route 45095 in direction 0 computed.
# route 45095 in direction 1 computed.
# route 54278 in direction 0 computed.
# route 54278 in direction 1 computed.
# route 45135 in direction 0 computed.
# route 45135 in direction 1 computed.
# route 45107 in direction 0 computed.
# route 45107 in direction 1 computed.
# route 66697 in direction 0 computed.
# route 66697 in direction 1 computed.
# route 61782 in direction 0 computed.
# route 61782 in direction 1 computed.
# route 45126 in direction 0 computed.
# route 45126 in direction 1 computed.
# route 54280 in direction 0 computed.
# route 54280 in direction 1 computed.
# route 54270 in direction 0 computed.
# route 54270 in direction 1 computed.
# route 61783 in direction 0 computed.
# route 61783 in direction 1 computed.
# route 45132 in direction 0 computed.
# route 45132 in direction 1 computed.
# route 45105 in direction 0 computed.
# route 45105 in direction 1 computed.
# route 54259 in direction 0 computed.
# route 54259 in direction 1 computed.
# route 45125 in direction 0 computed.
# route 45125 in direction 1 computed.
# route 54291 in direction 0 computed.
# route 54291 in direction 1 computed.
# route 66698 in direction 0 computed.
# route 66698 in direction 1 computed.
# route 54251 in direction 0 computed.
# route 54251 in direction 1 computed.
# route 45139 in direction 0 computed.
# route 45139 in direction 1 computed.
# route 61775 in direction 0 computed.
# route 61775 in direction 1 computed.
# route 54248 in direction 0 computed.
# route 54248 in direction 1 computed.
# route 45103 in direction 0 computed.
# route 45103 in direction 1 computed.
# route 54261 in direction 0 computed.
# route 54261 in direction 1 computed.
# route 54194 in direction 0 computed.
# route 54194 in direction 1 computed.
# route 54258 in direction 0 computed.
# route 54258 in direction 1 computed.
# route 54281 in direction 0 computed.
# route 54281 in direction 1 computed.
# route 54282 in direction 0 computed.
# route 54282 in direction 1 computed.
# route 45111 in direction 0 computed.
# route 45111 in direction 1 computed.
# route 54284 in direction 0 computed.
# route 54284 in direction 1 computed.
# route 61776 in direction 0 computed.
# route 61776 in direction 1 computed.
# route 62366 in direction 0 computed.
# route 62366 in direction 1 computed.
# route 61768 in direction 0 computed.
# route 61768 in direction 1 computed.
# route 45121 in direction 0 computed.
# route 45121 in direction 1 computed.
# route 45094 in direction 0 computed.
# route 45094 in direction 1 computed.
# route 61793 in direction 0 computed.
# route 61793 in direction 1 computed.
# route 54176 in direction 0 computed.
# route 54176 in direction 1 computed.
# route 54183 in direction 0 computed.
# route 54183 in direction 1 computed.
# route 67000 in direction 0 computed.
# route 67000 in direction 1 computed.
# route 54182 in direction 0 computed.
# route 54182 in direction 1 computed.
# route 54181 in direction 0 computed.
# route 54181 in direction 1 computed.
# route 66999 in direction 0 computed.
# route 66999 in direction 1 computed.
# route 54180 in direction 0 computed.
# route 54180 in direction 1 computed.
# route 54216 in direction 0 computed.
# route 54216 in direction 1 computed.
# route 54148 in direction 0 computed.
# route 54148 in direction 1 computed.
# route 54215 in direction 0 computed.
# route 54215 in direction 1 computed.
# route 54147 in direction 0 computed.
# route 54147 in direction 1 computed.
# route 54145 in direction 0 computed.
# route 54145 in direction 1 computed.
# route 54222 in direction 0 computed.
# route 54222 in direction 1 computed.
# route 54196 in direction 0 computed.
# route 54196 in direction 1 computed.
# route 75980 in direction 0 computed.
# route 75980 in direction 1 computed.
# route 75981 in direction 0 computed.
# route 75981 in direction 1 computed.
# route 75982 in direction 0 computed.
# route 75982 in direction 1 computed.
# route 75979 in direction 0 computed.
# route 75979 in direction 1 computed.
# route 75977 in direction 0 computed.
# route 75977 in direction 1 computed.
# route 75976 in direction 0 computed.
# route 75976 in direction 1 computed.
# route 75983 in direction 0 computed.
# route 75983 in direction 1 computed.
# route 75975 in direction 0 computed.
# route 75975 in direction 1 computed.
# route 75984 in direction 0 computed.
# route 75984 in direction 1 computed.
# route 75985 in direction 0 computed.
# route 75985 in direction 1 computed.
# route 54146 in direction 0 computed.
# route 54146 in direction 1 computed.
# route 75971 in direction 0 computed.
# route 75971 in direction 1 computed.
# route 75969 in direction 0 computed.
# route 75969 in direction 1 computed.
# route 66998 in direction 0 computed.
# route 66998 in direction 1 computed.
# route 75968 in direction 0 computed.
# route 75968 in direction 1 computed.
# route 75967 in direction 0 computed.
# route 75967 in direction 1 computed.
# route 54179 in direction 0 computed.
# route 54179 in direction 1 computed.
# route 54189 in direction 0 computed.
# route 54189 in direction 1 computed.
# route 54159 in direction 0 computed.
# route 54159 in direction 1 computed.
# route 54229 in direction 0 computed.
# route 54229 in direction 1 computed.
# route 61784 in direction 0 computed.
# route 61784 in direction 1 computed.
# route 54197 in direction 0 computed.
# route 54197 in direction 1 computed.
# route 54140 in direction 0 computed.
# route 54140 in direction 1 computed.
# route 75986 in direction 0 computed.
# route 75986 in direction 1 computed.
# route 54142 in direction 0 computed.
# route 54142 in direction 1 computed.
# route 54171 in direction 0 computed.
# route 54171 in direction 1 computed.
# route 54174 in direction 0 computed.
# route 54174 in direction 1 computed.
# route 54218 in direction 0 computed.
# route 54218 in direction 1 computed.
# route 67001 in direction 0 computed.
# route 67001 in direction 1 computed.
# route 54144 in direction 0 computed.
# route 54144 in direction 1 computed.
# route 54230 in direction 0 computed.
# route 54230 in direction 1 computed.
# route 54143 in direction 0 computed.
# route 54143 in direction 1 computed.
# route 75987 in direction 0 computed.
# route 75987 in direction 1 computed.
# route 66701 in direction 0 computed.
# route 66701 in direction 1 computed.
# route 314 in direction 0 computed.
# route 314 in direction 1 computed.
# route 42987 in direction 0 computed.
# route 42987 in direction 1 computed.
# route 61941 in direction 0 computed.
# route 61941 in direction 1 computed.
# route 61943 in direction 0 computed.
# route 61943 in direction 1 computed.
# route 41495 in direction 0 computed.
# route 41495 in direction 1 computed.
# route 53427 in direction 0 computed.
# route 53427 in direction 1 computed.
# route 66660 in direction 0 computed.
# route 66660 in direction 1 computed.
# route 66662 in direction 0 computed.
# route 66662 in direction 1 computed.
# route 75370 in direction 0 computed.
# route 75370 in direction 1 computed.
# route 75371 in direction 0 computed.
# route 75371 in direction 1 computed.
# route 67331 in direction 0 computed.
# route 67331 in direction 1 computed.
# route 66670 in direction 0 computed.
# route 66670 in direction 1 computed.
# route 41487 in direction 0 computed.
# route 41487 in direction 1 computed.
# route 41485 in direction 0 computed.
# route 41485 in direction 1 computed.
# route 75373 in direction 0 computed.
# route 75373 in direction 1 computed.
# route 75374 in direction 0 computed.
# route 75374 in direction 1 computed.
# route 75375 in direction 0 computed.
# route 75375 in direction 1 computed.
# route 53420 in direction 0 computed.
# route 53420 in direction 1 computed.
# route 53859 in direction 0 computed.
# route 53859 in direction 1 computed.
# route 66668 in direction 0 computed.
# route 66668 in direction 1 computed.
# route 75366 in direction 0 computed.
# route 75366 in direction 1 computed.
# route 53421 in direction 0 computed.
# route 53421 in direction 1 computed.
# route 61801 in direction 0 computed.
# route 61801 in direction 1 computed.
# route 45368 in direction 0 computed.
# route 45368 in direction 1 computed.
# route 75368 in direction 0 computed.
# route 75368 in direction 1 computed.
# route 74484 in direction 0 computed.
# route 74484 in direction 1 computed.
# route 41497 in direction 0 computed.
# route 41497 in direction 1 computed.
# route 53867 in direction 0 computed.
# route 53867 in direction 1 computed.
# route 53868 in direction 0 computed.
# route 53868 in direction 1 computed.
# route 41499 in direction 0 computed.
# route 41499 in direction 1 computed.
# route 53432 in direction 0 computed.
# route 53432 in direction 1 computed.
# route 62385 in direction 0 computed.
# route 62385 in direction 1 computed.
# route 53422 in direction 0 computed.
# route 53422 in direction 1 computed.
# route 41480 in direction 0 computed.
# route 41480 in direction 1 computed.
# route 53865 in direction 0 computed.
# route 53865 in direction 1 computed.
# route 45373 in direction 0 computed.
# route 45373 in direction 1 computed.
# route 74519 in direction 0 computed.
# route 74519 in direction 1 computed.
# route 74513 in direction 0 computed.
# route 74513 in direction 1 computed.
# route 75937 in direction 0 computed.
# route 75937 in direction 1 computed.
# route 74511 in direction 0 computed.
# route 74511 in direction 1 computed.
# route 52851 in direction 0 computed.
# route 52851 in direction 1 computed.
# route 52850 in direction 0 computed.
# route 52850 in direction 1 computed.
# route 74508 in direction 0 computed.
# route 74508 in direction 1 computed.
# route 74507 in direction 0 computed.
# route 74507 in direction 1 computed.
# route 52870 in direction 0 computed.
# route 52870 in direction 1 computed.
# route 74506 in direction 0 computed.
# route 74506 in direction 1 computed.
# route 74505 in direction 0 computed.
# route 74505 in direction 1 computed.
# route 43026 in direction 0 computed.
# route 43026 in direction 1 computed.
# route 43027 in direction 0 computed.
# route 43027 in direction 1 computed.
# route 74504 in direction 0 computed.
# route 74504 in direction 1 computed.
# route 53837 in direction 0 computed.
# route 53837 in direction 1 computed.
# route 74503 in direction 0 computed.
# route 74503 in direction 1 computed.
# route 52861 in direction 0 computed.
# route 52861 in direction 1 computed.
# route 74501 in direction 0 computed.
# route 74501 in direction 1 computed.
# route 74499 in direction 0 computed.
# route 74499 in direction 1 computed.
# route 54551 in direction 0 computed.
# route 54551 in direction 1 computed.
# route 61983 in direction 0 computed.
# route 61983 in direction 1 computed.
# route 74497 in direction 0 computed.
# route 74497 in direction 1 computed.
# route 54566 in direction 0 computed.
# route 54566 in direction 1 computed.
# route 61812 in direction 0 computed.
# route 61812 in direction 1 computed.
# route 52856 in direction 0 computed.
# route 52856 in direction 1 computed.
# route 74495 in direction 0 computed.
# route 74495 in direction 1 computed.
# route 74496 in direction 0 computed.
# route 74496 in direction 1 computed.
# route 54568 in direction 0 computed.
# route 54568 in direction 1 computed.
# route 43046 in direction 0 computed.
# route 43046 in direction 1 computed.
# route 61974 in direction 0 computed.
# route 61974 in direction 1 computed.
# route 74516 in direction 0 computed.
# route 74516 in direction 1 computed.
# route 74509 in direction 0 computed.
# route 74509 in direction 1 computed.
# route 43025 in direction 0 computed.
# route 43025 in direction 1 computed.
# route 53838 in direction 0 computed.
# route 53838 in direction 1 computed.
# route 43056 in direction 0 computed.
# route 43056 in direction 1 computed.
# route 52849 in direction 0 computed.
# route 52849 in direction 1 computed.
# route 74498 in direction 0 computed.
# route 74498 in direction 1 computed.
# route 61973 in direction 0 computed.
# route 61973 in direction 1 computed.
# route 52871 in direction 0 computed.
# route 52871 in direction 1 computed.
# route 43043 in direction 0 computed.
# route 43043 in direction 1 computed.
# route 45411 in direction 0 computed.
# route 45411 in direction 1 computed.
# route 45413 in direction 0 computed.
# route 45413 in direction 1 computed.
# route 45415 in direction 0 computed.
# route 45415 in direction 1 computed.
# route 41732 in direction 0 computed.
# route 41732 in direction 1 computed.
# route 60709 in direction 0 computed.
# route 60709 in direction 1 computed.
# route 74944 in direction 0 computed.
# route 74944 in direction 1 computed.
# route 62043 in direction 0 computed.
# route 62043 in direction 1 computed.
# route 62044 in direction 0 computed.
# route 62044 in direction 1 computed.
# route 41734 in direction 0 computed.
# route 41734 in direction 1 computed.
# route 74942 in direction 0 computed.
# route 74942 in direction 1 computed.
# route 230 in direction 0 computed.
# route 230 in direction 1 computed.
# route 62045 in direction 0 computed.
# route 62045 in direction 1 computed.
# route 41696 in direction 0 computed.
# route 41696 in direction 1 computed.
# route 222 in direction 0 computed.
# route 222 in direction 1 computed.
# route 198 in direction 0 computed.
# route 198 in direction 1 computed.
# route 196 in direction 0 computed.
# route 196 in direction 1 computed.
# route 41699 in direction 0 computed.
# route 41699 in direction 1 computed.
# route 41709 in direction 0 computed.
# route 41709 in direction 1 computed.
# route 246 in direction 0 computed.
# route 246 in direction 1 computed.
# route 41726 in direction 0 computed.
# route 41726 in direction 1 computed.
# route 62393 in direction 0 computed.
# route 62393 in direction 1 computed.
# route 257 in direction 0 computed.
# route 257 in direction 1 computed.
# route 255 in direction 0 computed.
# route 255 in direction 1 computed.
# route 254 in direction 0 computed.
# route 254 in direction 1 computed.
# route 41740 in direction 0 computed.
# route 41740 in direction 1 computed.
# route 58937 in direction 0 computed.
# route 58937 in direction 1 computed.
# route 211 in direction 0 computed.
# route 211 in direction 1 computed.
# route 53526 in direction 0 computed.
# route 53526 in direction 1 computed.
# route 206 in direction 0 computed.
# route 206 in direction 1 computed.
# route 199 in direction 0 computed.
# route 199 in direction 1 computed.
# route 235 in direction 0 computed.
# route 235 in direction 1 computed.
# route 62042 in direction 0 computed.
# route 62042 in direction 1 computed.
# route 203 in direction 0 computed.
# route 203 in direction 1 computed.
# route 33048 in direction 0 computed.
# route 33048 in direction 1 computed.
# route 41717 in direction 0 computed.
# route 41717 in direction 1 computed.
# route 74949 in direction 0 computed.
# route 74949 in direction 1 computed.
# route 74950 in direction 0 computed.
# route 74950 in direction 1 computed.
# route 53529 in direction 0 computed.
# route 53529 in direction 1 computed.
# route 41695 in direction 0 computed.
# route 41695 in direction 1 computed.
# route 62038 in direction 0 computed.
# route 62038 in direction 1 computed.
# route 41703 in direction 0 computed.
# route 41703 in direction 1 computed.
# route 41702 in direction 0 computed.
# route 41702 in direction 1 computed.
# route 41714 in direction 0 computed.
# route 41714 in direction 1 computed.
# route 41713 in direction 0 computed.
# route 41713 in direction 1 computed.
# route 67010 in direction 0 computed.
# route 67010 in direction 1 computed.
# route 74953 in direction 0 computed.
# route 74953 in direction 1 computed.
# route 74955 in direction 0 computed.
# route 74955 in direction 1 computed.
# route 74956 in direction 0 computed.
# route 74956 in direction 1 computed.
# route 41729 in direction 0 computed.
# route 41729 in direction 1 computed.
# route 41728 in direction 0 computed.
# route 41728 in direction 1 computed.
# route 67017 in direction 0 computed.
# route 67017 in direction 1 computed.
# route 41723 in direction 0 computed.
# route 41723 in direction 1 computed.
# route 67003 in direction 0 computed.
# route 67003 in direction 1 computed.
# route 41721 in direction 0 computed.
# route 41721 in direction 1 computed.
# route 123 in direction 0 computed.
# route 123 in direction 1 computed.
# route 60674 in direction 0 computed.
# route 60674 in direction 1 computed.
# route 475 in direction 0 computed.
# route 475 in direction 1 computed.
# route 60673 in direction 0 computed.
# route 60673 in direction 1 computed.
# route 473 in direction 0 computed.
# route 473 in direction 1 computed.
# route 471 in direction 0 computed.
# route 471 in direction 1 computed.
# route 63556 in direction 0 computed.
# route 63556 in direction 1 computed.
# route 455 in direction 0 computed.
# route 455 in direction 1 computed.
# route 67606 in direction 0 computed.
# route 67606 in direction 1 computed.
# route 74931 in direction 0 computed.
# route 74931 in direction 1 computed.
# route 75849 in direction 0 computed.
# route 75849 in direction 1 computed.
# route 61515 in direction 0 computed.
# route 61515 in direction 1 computed.
# route 63691 in direction 0 computed.
# route 63691 in direction 1 computed.
# route 75850 in direction 0 computed.
# route 75850 in direction 1 computed.
# route 75851 in direction 0 computed.
# route 75851 in direction 1 computed.
# route 65789 in direction 0 computed.
# route 65789 in direction 1 computed.
# route 6139 in direction 0 computed.
# route 6139 in direction 1 computed.
# route 75852 in direction 0 computed.
# route 75852 in direction 1 computed.
# route 460 in direction 0 computed.
# route 460 in direction 1 computed.
# route 462 in direction 0 computed.
# route 462 in direction 1 computed.
# route 439 in direction 0 computed.
# route 439 in direction 1 computed.
# route 73418 in direction 0 computed.
# route 73418 in direction 1 computed.
# route 59759 in direction 0 computed.
# route 59759 in direction 1 computed.
# route 75999 in direction 0 computed.
# route 75999 in direction 1 computed.
# route 428 in direction 0 computed.
# route 428 in direction 1 computed.
# route 427 in direction 0 computed.
# route 427 in direction 1 computed.
# route 441 in direction 0 computed.
# route 441 in direction 1 computed.
# route 60661 in direction 0 computed.
# route 60661 in direction 1 computed.
# route 75862 in direction 0 computed.
# route 75862 in direction 1 computed.
# route 60658 in direction 0 computed.
# route 60658 in direction 1 computed.
# route 60662 in direction 0 computed.
# route 60662 in direction 1 computed.
# route 73417 in direction 0 computed.
# route 73417 in direction 1 computed.
# route 67179 in direction 0 computed.
# route 67179 in direction 1 computed.
# route 482 in direction 0 computed.
# route 482 in direction 1 computed.
# route 67507 in direction 0 computed.
# route 67507 in direction 1 computed.
# route 73579 in direction 0 computed.
# route 73579 in direction 1 computed.
# route 41838 in direction 0 computed.
# route 41838 in direction 1 computed.
# route 62082 in direction 0 computed.
# route 62082 in direction 1 computed.
# route 62084 in direction 0 computed.
# route 62084 in direction 1 computed.
# route 41839 in direction 0 computed.
# route 41839 in direction 1 computed.
# route 41837 in direction 0 computed.
# route 41837 in direction 1 computed.
# route 41836 in direction 0 computed.
# route 41836 in direction 1 computed.
# route 41835 in direction 0 computed.
# route 41835 in direction 1 computed.
# route 62081 in direction 0 computed.
# route 62081 in direction 1 computed.
# route 71685 in direction 0 computed.
# route 71685 in direction 1 computed.
# route 75991 in direction 0 computed.
# route 75991 in direction 1 computed.
# route 67150 in direction 0 computed.
# route 67150 in direction 1 computed.
# route 67155 in direction 0 computed.
# route 67155 in direction 1 computed.
# route 67153 in direction 0 computed.
# route 67153 in direction 1 computed.
# route 67096 in direction 0 computed.
# route 67096 in direction 1 computed.
# route 67147 in direction 0 computed.
# route 67147 in direction 1 computed.
# route 67372 in direction 0 computed.
# route 67372 in direction 1 computed.
# route 67091 in direction 0 computed.
# route 67091 in direction 1 computed.
# route 75996 in direction 0 computed.
# route 75996 in direction 1 computed.
# route 73425 in direction 0 computed.
# route 73425 in direction 1 computed.
# route 74283 in direction 0 computed.
# route 74283 in direction 1 computed.
# route 75995 in direction 0 computed.
# route 75995 in direction 1 computed.
# route 75992 in direction 0 computed.
# route 75992 in direction 1 computed.
# route 67094 in direction 0 computed.
# route 67094 in direction 1 computed.
# route 67104 in direction 0 computed.
# route 67104 in direction 1 computed.
# route 67126 in direction 0 computed.
# route 67126 in direction 1 computed.
# route 67132 in direction 0 computed.
# route 67132 in direction 1 computed.
# route 75990 in direction 0 computed.
# route 75990 in direction 1 computed.
# route 73439 in direction 0 computed.
# route 73439 in direction 1 computed.
# route 67139 in direction 0 computed.
# route 67139 in direction 1 computed.
# route 67106 in direction 0 computed.
# route 67106 in direction 1 computed.
# route 67145 in direction 0 computed.
# route 67145 in direction 1 computed.
# route 67121 in direction 0 computed.
# route 67121 in direction 1 computed.
# route 67120 in direction 0 computed.
# route 67120 in direction 1 computed.
# route 67122 in direction 0 computed.
# route 67122 in direction 1 computed.
# route 73440 in direction 0 computed.
# route 73440 in direction 1 computed.
# route 67125 in direction 0 computed.
# route 67125 in direction 1 computed.
# route 67144 in direction 0 computed.
# route 67144 in direction 1 computed.
# route 74286 in direction 0 computed.
# route 74286 in direction 1 computed.
# route 67127 in direction 0 computed.
# route 67127 in direction 1 computed.
# route 76324 in direction 0 computed.
# route 76324 in direction 1 computed.
# route 67116 in direction 0 computed.
# route 67116 in direction 1 computed.
# route 67087 in direction 0 computed.
# route 67087 in direction 1 computed.
# route 67089 in direction 0 computed.
# route 67089 in direction 1 computed.
# route 67154 in direction 0 computed.
# route 67154 in direction 1 computed.
# route 67088 in direction 0 computed.
# route 67088 in direction 1 computed.
# route 67092 in direction 0 computed.
# route 67092 in direction 1 computed.
# route 67093 in direction 0 computed.
# route 67093 in direction 1 computed.
# route 67124 in direction 0 computed.
# route 67124 in direction 1 computed.
# route 75383 in direction 0 computed.
# route 75383 in direction 1 computed.
# route 75384 in direction 0 computed.
# route 75384 in direction 1 computed.
# route 75385 in direction 0 computed.
# route 75385 in direction 1 computed.
# route 75386 in direction 0 computed.
# route 75386 in direction 1 computed.
# route 75387 in direction 0 computed.
# route 75387 in direction 1 computed.
# route 75388 in direction 0 computed.
# route 75388 in direction 1 computed.
# route 75389 in direction 0 computed.
# route 75389 in direction 1 computed.
# route 75390 in direction 0 computed.
# route 75390 in direction 1 computed.
# route 75392 in direction 0 computed.
# route 75392 in direction 1 computed.
# route 75394 in direction 0 computed.
# route 75394 in direction 1 computed.
# route 75395 in direction 0 computed.
# route 75395 in direction 1 computed.
# route 75396 in direction 0 computed.
# route 75396 in direction 1 computed.
# route 75397 in direction 0 computed.
# route 75397 in direction 1 computed.
# route 75398 in direction 0 computed.
# route 75398 in direction 1 computed.
# route 75399 in direction 0 computed.
# route 75399 in direction 1 computed.
# route 75400 in direction 0 computed.
# route 75400 in direction 1 computed.
# route 75402 in direction 0 computed.
# route 75402 in direction 1 computed.
# route 75404 in direction 0 computed.
# route 75404 in direction 1 computed.
# route 75405 in direction 0 computed.
# route 75405 in direction 1 computed.
# route 75406 in direction 0 computed.
# route 75406 in direction 1 computed.
# route 75407 in direction 0 computed.
# route 75407 in direction 1 computed.
# route 75408 in direction 0 computed.
# route 75408 in direction 1 computed.
# route 75409 in direction 0 computed.
# route 75409 in direction 1 computed.
# route 75411 in direction 0 computed.
# route 75411 in direction 1 computed.
# route 75413 in direction 0 computed.
# route 75413 in direction 1 computed.
# route 75414 in direction 0 computed.
# route 75414 in direction 1 computed.
# route 75416 in direction 0 computed.
# route 75416 in direction 1 computed.
# route 75417 in direction 0 computed.
# route 75417 in direction 1 computed.
# route 75420 in direction 0 computed.
# route 75420 in direction 1 computed.
# route 75423 in direction 0 computed.
# route 75423 in direction 1 computed.
# route 75424 in direction 0 computed.
# route 75424 in direction 1 computed.
# route 75428 in direction 0 computed.
# route 75428 in direction 1 computed.
# route 75429 in direction 0 computed.
# route 75429 in direction 1 computed.
# route 75431 in direction 0 computed.
# route 75431 in direction 1 computed.
# route 75432 in direction 0 computed.
# route 75432 in direction 1 computed.
# route 75433 in direction 0 computed.
# route 75433 in direction 1 computed.
# route 75435 in direction 0 computed.
# route 75435 in direction 1 computed.
# route 75457 in direction 0 computed.
# route 75457 in direction 1 computed.
# route 75459 in direction 0 computed.
# route 75459 in direction 1 computed.
# route 75461 in direction 0 computed.
# route 75461 in direction 1 computed.
# route 75462 in direction 0 computed.
# route 75462 in direction 1 computed.
# route 75463 in direction 0 computed.
# route 75463 in direction 1 computed.
# route 75464 in direction 0 computed.
# route 75464 in direction 1 computed.
# route 75467 in direction 0 computed.
# route 75467 in direction 1 computed.
# route 75468 in direction 0 computed.
# route 75468 in direction 1 computed.
# route 75469 in direction 0 computed.
# route 75469 in direction 1 computed.
# route 75470 in direction 0 computed.
# route 75470 in direction 1 computed.
# route 75472 in direction 0 computed.
# route 75472 in direction 1 computed.
# route 75473 in direction 0 computed.
# route 75473 in direction 1 computed.
# route 75474 in direction 0 computed.
# route 75474 in direction 1 computed.
# route 75475 in direction 0 computed.
# route 75475 in direction 1 computed.
# route 75476 in direction 0 computed.
# route 75476 in direction 1 computed.
# route 75477 in direction 0 computed.
# route 75477 in direction 1 computed.
# route 75478 in direction 0 computed.
# route 75478 in direction 1 computed.
# route 75479 in direction 0 computed.
# route 75479 in direction 1 computed.
# route 75480 in direction 0 computed.
# route 75480 in direction 1 computed.
# route 75481 in direction 0 computed.
# route 75481 in direction 1 computed.
# route 75482 in direction 0 computed.
# route 75482 in direction 1 computed.
# route 75483 in direction 0 computed.
# route 75483 in direction 1 computed.
# route 75484 in direction 0 computed.
# route 75484 in direction 1 computed.
# route 75485 in direction 0 computed.
# route 75485 in direction 1 computed.
# route 75486 in direction 0 computed.
# route 75486 in direction 1 computed.
# route 75488 in direction 0 computed.
# route 75488 in direction 1 computed.
# route 75490 in direction 0 computed.
# route 75490 in direction 1 computed.
# route 75491 in direction 0 computed.
# route 75491 in direction 1 computed.
# route 75492 in direction 0 computed.
# route 75492 in direction 1 computed.
# route 75493 in direction 0 computed.
# route 75493 in direction 1 computed.
# route 75494 in direction 0 computed.
# route 75494 in direction 1 computed.
# route 75495 in direction 0 computed.
# route 75495 in direction 1 computed.
# route 75496 in direction 0 computed.
# route 75496 in direction 1 computed.
# route 75497 in direction 0 computed.
# route 75497 in direction 1 computed.
# route 75498 in direction 0 computed.
# route 75498 in direction 1 computed.
# route 75499 in direction 0 computed.
# route 75499 in direction 1 computed.
# route 75500 in direction 0 computed.
# route 75500 in direction 1 computed.
# route 75501 in direction 0 computed.
# route 75501 in direction 1 computed.
# route 75502 in direction 0 computed.
# route 75502 in direction 1 computed.
# route 75504 in direction 0 computed.
# route 75504 in direction 1 computed.
# route 75505 in direction 0 computed.
# route 75505 in direction 1 computed.
# route 75509 in direction 0 computed.
# route 75509 in direction 1 computed.
# route 75510 in direction 0 computed.
# route 75510 in direction 1 computed.
# route 75511 in direction 0 computed.
# route 75511 in direction 1 computed.
# route 75512 in direction 0 computed.
# route 75512 in direction 1 computed.
# route 75513 in direction 0 computed.
# route 75513 in direction 1 computed.
# route 75514 in direction 0 computed.
# route 75514 in direction 1 computed.
# route 75515 in direction 0 computed.
# route 75515 in direction 1 computed.
# route 75516 in direction 0 computed.
# route 75516 in direction 1 computed.
# route 75517 in direction 0 computed.
# route 75517 in direction 1 computed.
# route 75518 in direction 0 computed.
# route 75518 in direction 1 computed.
# route 75520 in direction 0 computed.
# route 75520 in direction 1 computed.
# route 75521 in direction 0 computed.
# route 75521 in direction 1 computed.
# route 75522 in direction 0 computed.
# route 75522 in direction 1 computed.
# route 75524 in direction 0 computed.
# route 75524 in direction 1 computed.
# route 75525 in direction 0 computed.
# route 75525 in direction 1 computed.
# route 75528 in direction 0 computed.
# route 75528 in direction 1 computed.
# route 75529 in direction 0 computed.
# route 75529 in direction 1 computed.
# route 75530 in direction 0 computed.
# route 75530 in direction 1 computed.
# route 75532 in direction 0 computed.
# route 75532 in direction 1 computed.
# route 75533 in direction 0 computed.
# route 75533 in direction 1 computed.
# route 75534 in direction 0 computed.
# route 75534 in direction 1 computed.
# route 75535 in direction 0 computed.
# route 75535 in direction 1 computed.
# route 75536 in direction 0 computed.
# route 75536 in direction 1 computed.
# route 75537 in direction 0 computed.
# route 75537 in direction 1 computed.
# route 75545 in direction 0 computed.
# route 75545 in direction 1 computed.
# route 75546 in direction 0 computed.
# route 75546 in direction 1 computed.
# route 75547 in direction 0 computed.
# route 75547 in direction 1 computed.
# route 75548 in direction 0 computed.
# route 75548 in direction 1 computed.
# route 75549 in direction 0 computed.
# route 75549 in direction 1 computed.
# route 75551 in direction 0 computed.
# route 75551 in direction 1 computed.
# route 75552 in direction 0 computed.
# route 75552 in direction 1 computed.
# route 75553 in direction 0 computed.
# route 75553 in direction 1 computed.
# route 75555 in direction 0 computed.
# route 75555 in direction 1 computed.
# route 75557 in direction 0 computed.
# route 75557 in direction 1 computed.
# route 75558 in direction 0 computed.
# route 75558 in direction 1 computed.
# route 75559 in direction 0 computed.
# route 75559 in direction 1 computed.
# route 75560 in direction 0 computed.
# route 75560 in direction 1 computed.
# route 75561 in direction 0 computed.
# route 75561 in direction 1 computed.
# route 75562 in direction 0 computed.
# route 75562 in direction 1 computed.
# route 75564 in direction 0 computed.
# route 75564 in direction 1 computed.
# route 75565 in direction 0 computed.
# route 75565 in direction 1 computed.
# route 76325 in direction 0 computed.
# route 76325 in direction 1 computed.
# route 76326 in direction 0 computed.
# route 76326 in direction 1 computed.
# route 75567 in direction 0 computed.
# route 75567 in direction 1 computed.
# route 75568 in direction 0 computed.
# route 75568 in direction 1 computed.
# route 75569 in direction 0 computed.
# route 75569 in direction 1 computed.
# route 75570 in direction 0 computed.
# route 75570 in direction 1 computed.
# route 75572 in direction 0 computed.
# route 75572 in direction 1 computed.
# route 75574 in direction 0 computed.
# route 75574 in direction 1 computed.
# route 75575 in direction 0 computed.
# route 75575 in direction 1 computed.
# route 75577 in direction 0 computed.
# route 75577 in direction 1 computed.
# route 75578 in direction 0 computed.
# route 75578 in direction 1 computed.
# route 75579 in direction 0 computed.
# route 75579 in direction 1 computed.
# route 76327 in direction 0 computed.
# route 76327 in direction 1 computed.
# route 75581 in direction 0 computed.
# route 75581 in direction 1 computed.
# route 75582 in direction 0 computed.
# route 75582 in direction 1 computed.
# route 75583 in direction 0 computed.
# route 75583 in direction 1 computed.
# route 75585 in direction 0 computed.
# route 75585 in direction 1 computed.
# route 75586 in direction 0 computed.
# route 75586 in direction 1 computed.
# route 76328 in direction 0 computed.
# route 76328 in direction 1 computed.
# route 75592 in direction 0 computed.
# route 75592 in direction 1 computed.
# route 75593 in direction 0 computed.
# route 75593 in direction 1 computed.
# route 75595 in direction 0 computed.
# route 75595 in direction 1 computed.
# route 75599 in direction 0 computed.
# route 75599 in direction 1 computed.
# route 75601 in direction 0 computed.
# route 75601 in direction 1 computed.
# route 75602 in direction 0 computed.
# route 75602 in direction 1 computed.
# route 75604 in direction 0 computed.
# route 75604 in direction 1 computed.
# route 75610 in direction 0 computed.
# route 75610 in direction 1 computed.
# route 75611 in direction 0 computed.
# route 75611 in direction 1 computed.
# route 75612 in direction 0 computed.
# route 75612 in direction 1 computed.
# route 75614 in direction 0 computed.
# route 75614 in direction 1 computed.
# route 75615 in direction 0 computed.
# route 75615 in direction 1 computed.
# route 75616 in direction 0 computed.
# route 75616 in direction 1 computed.
# route 75620 in direction 0 computed.
# route 75620 in direction 1 computed.
# route 75621 in direction 0 computed.
# route 75621 in direction 1 computed.
# route 75626 in direction 0 computed.
# route 75626 in direction 1 computed.
# route 75627 in direction 0 computed.
# route 75627 in direction 1 computed.
# route 75628 in direction 0 computed.
# route 75628 in direction 1 computed.
# route 75629 in direction 0 computed.
# route 75629 in direction 1 computed.
# route 75631 in direction 0 computed.
# route 75631 in direction 1 computed.
# route 75632 in direction 0 computed.
# route 75632 in direction 1 computed.
# route 75634 in direction 0 computed.
# route 75634 in direction 1 computed.
# route 75635 in direction 0 computed.
# route 75635 in direction 1 computed.
# route 75636 in direction 0 computed.
# route 75636 in direction 1 computed.
# route 75638 in direction 0 computed.
# route 75638 in direction 1 computed.
# route 75639 in direction 0 computed.
# route 75639 in direction 1 computed.
# route 75641 in direction 0 computed.
# route 75641 in direction 1 computed.
# route 75642 in direction 0 computed.
# route 75642 in direction 1 computed.
# route 75647 in direction 0 computed.
# route 75647 in direction 1 computed.
# route 75648 in direction 0 computed.
# route 75648 in direction 1 computed.
# route 75654 in direction 0 computed.
# route 75654 in direction 1 computed.
# route 75661 in direction 0 computed.
# route 75661 in direction 1 computed.
# route 17658 in direction 0 computed.
# route 17658 in direction 1 computed.
# route 17828 in direction 0 computed.
# route 17828 in direction 1 computed.
# route 17782 in direction 0 computed.
# route 17782 in direction 1 computed.
# route 41238 in direction 0 computed.
# route 41238 in direction 1 computed.
# route 46092 in direction 0 computed.
# route 46092 in direction 1 computed.
# route 41206 in direction 0 computed.
# route 41206 in direction 1 computed.
# route 41202 in direction 0 computed.
# route 41202 in direction 1 computed.
# route 67412 in direction 0 computed.
# route 67412 in direction 1 computed.
# route 41226 in direction 0 computed.
# route 41226 in direction 1 computed.
# route 61914 in direction 0 computed.
# route 61914 in direction 1 computed.
# route 17792 in direction 0 computed.
# route 17792 in direction 1 computed.
# route 46084 in direction 0 computed.
# route 46084 in direction 1 computed.
# route 73489 in direction 0 computed.
# route 73489 in direction 1 computed.
# route 66117 in direction 0 computed.
# route 66117 in direction 1 computed.
# route 17573 in direction 0 computed.
# route 17573 in direction 1 computed.
# route 41208 in direction 0 computed.
# route 41208 in direction 1 computed.
# route 76125 in direction 0 computed.
# route 76125 in direction 1 computed.
# route 76122 in direction 0 computed.
# route 76122 in direction 1 computed.
# route 17615 in direction 0 computed.
# route 17615 in direction 1 computed.
# route 76120 in direction 0 computed.
# route 76120 in direction 1 computed.
# route 41236 in direction 0 computed.
# route 41236 in direction 1 computed.
# route 76128 in direction 0 computed.
# route 76128 in direction 1 computed.
# route 76127 in direction 0 computed.
# route 76127 in direction 1 computed.
# route 41216 in direction 0 computed.
# route 41216 in direction 1 computed.
# route 52993 in direction 0 computed.
# ...
# route 62948 in direction 0 computed.
# route 62948 in direction 1 computed.
# route 62577 in direction 0 computed.
# route 62577 in direction 1 computed.
# route 62714 in direction 0 computed.
# route 62714 in direction 1 computed.
# route 62719 in direction 0 computed.
# route 62719 in direction 1 computed.
# route 62638 in direction 0 computed.
# route 62638 in direction 1 computed.
# route 62772 in direction 0 computed.
# route 62772 in direction 1 computed.
# route 62729 in direction 0 computed.
# route 62729 in direction 1 computed.
# route 62976 in direction 0 computed.
# route 62976 in direction 1 computed.
# route 62570 in direction 0 computed.
# route 62570 in direction 1 computed.
# route 62671 in direction 0 computed.
# route 62671 in direction 1 computed.
# route 62765 in direction 0 computed.
# route 62765 in direction 1 computed.
# route 62936 in direction 0 computed.
# route 62936 in direction 1 computed.
# route 62938 in direction 0 computed.
# route 62938 in direction 1 computed.
# route 62652 in direction 0 computed.
# route 62652 in direction 1 computed.
# route 76158 in direction 0 computed.
# route 76158 in direction 1 computed.
# route 62799 in direction 0 computed.
# route 62799 in direction 1 computed.
# route 62923 in direction 0 computed.
# route 62923 in direction 1 computed.
# route 62663 in direction 0 computed.
# route 62663 in direction 1 computed.
# route 62876 in direction 0 computed.
# route 62876 in direction 1 computed.
# route 62585 in direction 0 computed.
# route 62585 in direction 1 computed.
# route 62583 in direction 0 computed.
# route 62583 in direction 1 computed.
# route 75986 in direction 0 computed.
# route 75986 in direction 1 computed.
# route 31664 in direction 0 computed.
# route 31664 in direction 1 computed.
# route 74285 in direction 0 computed.
# route 74285 in direction 1 computed.
# route 75477 in direction 0 computed.
# route 75477 in direction 1 computed.
# route 67399 in direction 0 computed.
# route 67399 in direction 1 computed.
# route 75043 in direction 0 computed.
# route 75043 in direction 1 computed.
# route 17601 in direction 0 computed.
# route 17601 in direction 1 computed.
# route 61050 in direction 0 computed.
# route 61050 in direction 1 computed.
# route 71409 in direction 0 computed.
# route 71409 in direction 1 computed.
# route 75829 in direction 0 computed.
# route 75829 in direction 1 computed.
# route 61948 in direction 0 computed.
# route 61948 in direction 1 computed.
# route 75333 in direction 0 computed.
# route 75333 in direction 1 computed.
# route 62891 in direction 0 computed.
# route 62891 in direction 1 computed.
# route 62561 in direction 0 computed.
# route 62561 in direction 1 computed.
# route 62846 in direction 0 computed.
# route 62846 in direction 1 computed.
# route 62708 in direction 0 computed.
# route 62708 in direction 1 computed.
# route 62761 in direction 0 computed.
# route 62761 in direction 1 computed.
# route 62863 in direction 0 computed.
# route 62863 in direction 1 computed.
# route 62956 in direction 0 computed.
# route 62956 in direction 1 computed.
# route 62619 in direction 0 computed.
# route 62619 in direction 1 computed.
# route 76077 in direction 0 computed.
# route 76077 in direction 1 computed.
# route 62774 in direction 0 computed.
# route 62774 in direction 1 computed.
# route 62937 in direction 0 computed.
# route 62937 in direction 1 computed.
# route 62622 in direction 0 computed.
# route 62622 in direction 1 computed.
# route 62928 in direction 0 computed.
# route 62928 in direction 1 computed.
# route 62910 in direction 0 computed.
# route 62910 in direction 1 computed.
# route 62648 in direction 0 computed.
# route 62648 in direction 1 computed.
# route 62584 in direction 0 computed.
# route 62584 in direction 1 computed.
# route 62640 in direction 0 computed.
# route 62640 in direction 1 computed.
# route 76318 in direction 0 computed.
# route 76318 in direction 1 computed.
# route 62690 in direction 0 computed.
# route 62690 in direction 1 computed.
# route 62626 in direction 0 computed.
# route 62626 in direction 1 computed.
# route 62679 in direction 0 computed.
# route 62679 in direction 1 computed.
# route 62934 in direction 0 computed.
# route 62934 in direction 1 computed.
# route 76090 in direction 0 computed.
# route 76090 in direction 1 computed.
# route 62612 in direction 0 computed.
# route 62612 in direction 1 computed.
# route 62987 in direction 0 computed.
# route 62987 in direction 1 computed.
# route 71223 in direction 0 computed.
# route 71223 in direction 1 computed.
# route 317 in direction 0 computed.
# route 317 in direction 1 computed.
# route 76351 in direction 0 computed.
# route 76351 in direction 1 computed.
# route 69557 in direction 0 computed.
# route 69557 in direction 1 computed.
# route 62598 in direction 0 computed.
# route 62598 in direction 1 computed.
# route 76156 in direction 0 computed.
# route 76156 in direction 1 computed.
# route 62859 in direction 0 computed.
# route 62859 in direction 1 computed.
# route 62587 in direction 0 computed.
# route 62587 in direction 1 computed.
# route 62591 in direction 0 computed.
# route 62591 in direction 1 computed.
# route 62778 in direction 0 computed.
# route 62778 in direction 1 computed.
# route 76073 in direction 0 computed.
# route 76073 in direction 1 computed.
# route 62957 in direction 0 computed.
# route 62957 in direction 1 computed.
# route 62964 in direction 0 computed.
# route 62964 in direction 1 computed.
# route 62839 in direction 0 computed.
# route 62839 in direction 1 computed.
# route 62592 in direction 0 computed.
# route 62592 in direction 1 computed.
# route 62653 in direction 0 computed.
# route 62653 in direction 1 computed.
# route 62990 in direction 0 computed.
# route 62990 in direction 1 computed.
# route 62647 in direction 0 computed.
# route 62647 in direction 1 computed.
# route 62582 in direction 0 computed.
# route 62582 in direction 1 computed.
# route 62628 in direction 0 computed.
# route 62628 in direction 1 computed.
# route 75370 in direction 0 computed.
# route 75370 in direction 1 computed.
# route 62605 in direction 0 computed.
# route 62605 in direction 1 computed.
# route 62974 in direction 0 computed.
# route 62974 in direction 1 computed.
# route 62865 in direction 0 computed.
# route 62865 in direction 1 computed.
# route 62919 in direction 0 computed.
# route 62919 in direction 1 computed.
# route 76082 in direction 0 computed.
# route 76082 in direction 1 computed.
# route 75821 in direction 0 computed.
# route 75821 in direction 1 computed.
# route 76004 in direction 0 computed.
# route 76004 in direction 1 computed.
# route 62675 in direction 0 computed.
# route 62675 in direction 1 computed.
# route 62559 in direction 0 computed.
# route 62559 in direction 1 computed.
# route 62658 in direction 0 computed.
# route 62658 in direction 1 computed.
# route 19411 in direction 0 computed.
# route 19411 in direction 1 computed.
# route 76164 in direction 0 computed.
# route 76164 in direction 1 computed.
# route 61945 in direction 0 computed.
# route 61945 in direction 1 computed.
# route 61961 in direction 0 computed.
# route 61961 in direction 1 computed.
# route 62556 in direction 0 computed.
# route 62556 in direction 1 computed.
# route 62914 in direction 0 computed.
# route 62914 in direction 1 computed.
# route 62608 in direction 0 computed.
# route 62608 in direction 1 computed.
# route 62751 in direction 0 computed.
# route 62751 in direction 1 computed.
# route 62908 in direction 0 computed.
# route 62908 in direction 1 computed.
# route 62575 in direction 0 computed.
# route 62575 in direction 1 computed.
# route 62844 in direction 0 computed.
# route 62844 in direction 1 computed.
# route 76157 in direction 0 computed.
# route 76157 in direction 1 computed.
# route 62666 in direction 0 computed.
# route 62666 in direction 1 computed.
# route 62688 in direction 0 computed.
# route 62688 in direction 1 computed.
# route 62875 in direction 0 computed.
# route 62875 in direction 1 computed.
# route 71222 in direction 0 computed.
# route 71222 in direction 1 computed.
# route 316 in direction 0 computed.
# route 316 in direction 1 computed.
# route 50060 in direction 0 computed.
# route 50060 in direction 1 computed.
# route 75943 in direction 0 computed.
# route 75943 in direction 1 computed.
# route 75332 in direction 0 computed.
# route 75332 in direction 1 computed.
# route 62952 in direction 0 computed.
# route 62952 in direction 1 computed.
# route 62724 in direction 0 computed.
# route 62724 in direction 1 computed.
# route 62929 in direction 0 computed.
# route 62929 in direction 1 computed.
# route 62921 in direction 0 computed.
# route 62921 in direction 1 computed.
# route 62683 in direction 0 computed.
# route 62683 in direction 1 computed.
# route 62613 in direction 0 computed.
# route 62613 in direction 1 computed.
# route 62611 in direction 0 computed.
# route 62611 in direction 1 computed.
# route 62815 in direction 0 computed.
# route 62815 in direction 1 computed.
# route 76091 in direction 0 computed.
# route 76091 in direction 1 computed.
# route 62806 in direction 0 computed.
# route 62806 in direction 1 computed.
# route 62940 in direction 0 computed.
# route 62940 in direction 1 computed.
# route 62954 in direction 0 computed.
# route 62954 in direction 1 computed.
# route 67365 in direction 0 computed.
# route 67365 in direction 1 computed.
# route 62984 in direction 0 computed.
# route 62984 in direction 1 computed.
# route 61766 in direction 0 computed.
# route 61766 in direction 1 computed.
# route 313 in direction 0 computed.
# route 313 in direction 1 computed.
# route 62991 in direction 0 computed.
# route 62991 in direction 1 computed.
# route 62757 in direction 0 computed.
# route 62757 in direction 1 computed.
# route 62917 in direction 0 computed.
# route 62917 in direction 1 computed.
# route 62717 in direction 0 computed.
# route 62717 in direction 1 computed.
# route 62884 in direction 0 computed.
# route 62884 in direction 1 computed.
# route 62735 in direction 0 computed.
# route 62735 in direction 1 computed.
# route 75853 in direction 0 computed.
# route 75853 in direction 1 computed.
# route 62687 in direction 0 computed.
# route 62687 in direction 1 computed.
# route 43043 in direction 0 computed.
# route 43043 in direction 1 computed.
# route 62870 in direction 0 computed.
# route 62870 in direction 1 computed.
# route 62989 in direction 0 computed.
# route 62989 in direction 1 computed.
# route 62744 in direction 0 computed.
# route 62744 in direction 1 computed.
# route 62705 in direction 0 computed.
# route 62705 in direction 1 computed.
# route 62755 in direction 0 computed.
# route 62755 in direction 1 computed.
# route 52498 in direction 0 computed.
# route 52498 in direction 1 computed.
# route 62614 in direction 0 computed.
# route 62614 in direction 1 computed.
# route 62649 in direction 0 computed.
# route 62649 in direction 1 computed.
# route 62924 in direction 0 computed.
# route 62924 in direction 1 computed.
# route 76075 in direction 0 computed.
# route 76075 in direction 1 computed.
# route 62586 in direction 0 computed.
# route 62586 in direction 1 computed.
# route 76093 in direction 0 computed.
# route 76093 in direction 1 computed.
# route 61964 in direction 0 computed.
# route 61964 in direction 1 computed.
# route 61946 in direction 0 computed.
# route 61946 in direction 1 computed.
# route 76071 in direction 0 computed.
# route 76071 in direction 1 computed.
# route 62670 in direction 0 computed.
# route 62670 in direction 1 computed.
# route 62960 in direction 0 computed.
# route 62960 in direction 1 computed.
# route 62700 in direction 0 computed.
# route 62700 in direction 1 computed.
# route 62696 in direction 0 computed.
# route 62696 in direction 1 computed.
# route 62743 in direction 0 computed.
# route 62743 in direction 1 computed.
# route 62869 in direction 0 computed.
# route 62869 in direction 1 computed.
# route 62758 in direction 0 computed.
# route 62758 in direction 1 computed.
# route 62707 in direction 0 computed.
# route 62707 in direction 1 computed.
# route 62752 in direction 0 computed.
# route 62752 in direction 1 computed.
# route 62800 in direction 0 computed.
# route 62800 in direction 1 computed.
# route 62955 in direction 0 computed.
# route 62955 in direction 1 computed.
# route 62715 in direction 0 computed.
# route 62715 in direction 1 computed.
# route 62676 in direction 0 computed.
# route 62676 in direction 1 computed.
# route 62763 in direction 0 computed.
# route 62763 in direction 1 computed.
# route 62737 in direction 0 computed.
# route 62737 in direction 1 computed.
# route 62741 in direction 0 computed.
# route 62741 in direction 1 computed.
# route 62681 in direction 0 computed.
# route 62681 in direction 1 computed.
# route 75857 in direction 0 computed.
# route 75857 in direction 1 computed.
# route 75858 in direction 0 computed.
# route 75858 in direction 1 computed.
# route 75859 in direction 0 computed.
# route 75859 in direction 1 computed.
# route 75860 in direction 0 computed.
# route 75860 in direction 1 computed.
# route 75861 in direction 0 computed.
# route 75861 in direction 1 computed.
# route 75863 in direction 0 computed.
# route 75863 in direction 1 computed.
# route 44942 in direction 0 computed.
# route 44942 in direction 1 computed.
# route 61958 in direction 0 computed.
# route 61958 in direction 1 computed.
# route 62701 in direction 0 computed.
# route 62701 in direction 1 computed.
# route 62985 in direction 0 computed.
# route 62985 in direction 1 computed.
# route 62756 in direction 0 computed.
# route 62756 in direction 1 computed.
# route 62581 in direction 0 computed.
# route 62581 in direction 1 computed.
# route 62992 in direction 0 computed.
# route 62992 in direction 1 computed.
# route 62749 in direction 0 computed.
# route 62749 in direction 1 computed.
# route 62745 in direction 0 computed.
# route 62745 in direction 1 computed.
# route 62686 in direction 0 computed.
# route 62686 in direction 1 computed.
# route 62617 in direction 0 computed.
# route 62617 in direction 1 computed.
# route 62677 in direction 0 computed.
# route 62677 in direction 1 computed.
# route 62704 in direction 0 computed.
# route 62704 in direction 1 computed.
# route 62826 in direction 0 computed.
# route 62826 in direction 1 computed.
# route 62951 in direction 0 computed.
# route 62951 in direction 1 computed.
# route 61949 in direction 0 computed.
# route 61949 in direction 1 computed.
# route 62621 in direction 0 computed.
# route 62621 in direction 1 computed.
# route 62963 in direction 0 computed.
# route 62963 in direction 1 computed.
# route 62698 in direction 0 computed.
# route 62698 in direction 1 computed.
# route 62747 in direction 0 computed.
# route 62747 in direction 1 computed.
# route 62907 in direction 0 computed.
# route 62907 in direction 1 computed.
# route 62615 in direction 0 computed.
# route 62615 in direction 1 computed.
# route 62825 in direction 0 computed.
# route 62825 in direction 1 computed.
# route 62711 in direction 0 computed.
# route 62711 in direction 1 computed.
# route 62669 in direction 0 computed.
# route 62669 in direction 1 computed.
# route 62760 in direction 0 computed.
# route 62760 in direction 1 computed.
# route 62665 in direction 0 computed.
# route 62665 in direction 1 computed.
# route 62558 in direction 0 computed.
# route 62558 in direction 1 computed.
# route 62739 in direction 0 computed.
# route 62739 in direction 1 computed.
# route 62736 in direction 0 computed.
# route 62736 in direction 1 computed.
# route 62759 in direction 0 computed.
# route 62759 in direction 1 computed.
# route 62685 in direction 0 computed.
# route 62685 in direction 1 computed.
# route 62813 in direction 0 computed.
# route 62813 in direction 1 computed.
# route 75864 in direction 0 computed.
# route 75864 in direction 1 computed.
# route 76354 in direction 0 computed.
# route 76354 in direction 1 computed.
# route 62750 in direction 0 computed.
# route 62750 in direction 1 computed.
# route 62557 in direction 0 computed.
# route 62557 in direction 1 computed.
# route 62805 in direction 0 computed.
# route 62805 in direction 1 computed.
# route 62554 in direction 0 computed.
# route 62554 in direction 1 computed.
# route 62555 in direction 0 computed.
# route 62555 in direction 1 computed.
# route 62589 in direction 0 computed.
# route 62589 in direction 1 computed.
# route 76072 in direction 0 computed.
# route 76072 in direction 1 computed.
# route 62821 in direction 0 computed.
# route 62821 in direction 1 computed.
# Successfully extracted the time schedule table for sunday-20210124

# %% [markdown]
# ### Generate the README.txt accompanying the schedule tables

# %%
#Create the README.txt file
readme_text = "The files in this folder correspond to the transit time schedules. Each file is \n\
based on a typical day of the month (weekday, Saturday and Sunday). The following \n\
are the fields in each of the files. \n\
\n\
route_id	: The field provides the identifier corresponding to the route. \n\
The routes.txt file can be used to obtain more info.\n\
\n\
direction_id	: route_id is the same for all trips in a route irrespective of their direction. \n\
direction_id is used to differentiate trips in opposite directions.\n\
\n\
start_time	: This field provides arrays of start times of trips in the same route in a day. \n\
This can be used to initiate/schedule the trips on all route.\n\
\n\
stop_sequence	: This field provides arrays of the stops on a route (direction sensitive). \n\
\n\
inter_stop_tt	: This field provides the array of inter-stop travel times. \n\
The number of entries in an array would be one less than that in the stop_sequence array.\n\
\n\
The following dates were used to create the time-schedule tables.\n\
\n\
{0}saturday.csv	: {1}\n\
{0}sunday.csv	: {2}\n\
{0}weekday.csv	: {3}\n\
\n\
Notes:\n\
\n\
1. The time tables are generated using the GTFS dataset for {4} available at \n\
https://transitfeeds.com/p/ov/814/{4}/download\n\
2. Return trip details on some of the routes are not available. Mostly for long-distance routes.".format(month_year_text,
                                                                                                         day_list['saturday'],
                                                                                                        day_list['sunday'],
                                                                                                        day_list['weekday'],
                                                                                                        FIL_DATE)
#print(readme_text)
textfile = open('{0}README.txt'.format(folder), 'w')
textfile.write(readme_text)
textfile.close()
# Out:
# The files in this folder correspond to the transit time schedules. Each file is
# based on a typical day of the month (weekday, Saturday and Sunday). The following
# are the fields in each of the files.
#
# route_id	: The field provides the identifier corresponding to the route.
# The routes.txt file can be used to obtain more info.
#
# direction_id	: route_id is the same for all trips in a route irrespective of their direction.
# direction_id is used to differentiate trips in opposite directions.
#
# start_time	: This field provides arrays of start times of trips in the same route in a day.
# This can be used to initiate/schedule the trips on all route.
#
# stop_sequence	: This field provides arrays of the stops on a route (direction sensitive).
#
# inter_stop_tt	: This field provides the array of inter-stop travel times.
# The number of entries in an array would be one less than that in the stop_sequence array.
#
# The following dates were used to create the time-schedule tables.
#
# Jan2021_saturday.csv	: 20210123
# Jan2021_sunday.csv	: 20210124
# Jan2021_weekday.csv	: 20210121
#
# Notes:
#
# 1. The time tables are generated using the GTFS dataset for 20210104 available at
# https://transitfeeds.com/p/ov/814/20210104/download
# 2. Return trip details on some of the routes are not available. Mostly for long-distance routes.
